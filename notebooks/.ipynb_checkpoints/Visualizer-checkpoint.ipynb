# %%
import chess #https://github.com/niklasf/python-chess
from stockfish import Stockfish

import chess.pgn
import pandas as pd
pd.options.display.max_columns=999
import datetime
import tqdm
import zipfile
import numpy as np
import json
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# laod in games
games = pd.read_json("../../testData/games.json", orient='records', lines=True)
with open("../../testData/games_analysis.json", "r") as file:
    games_analysis = json.load(file) 
games_analysis = [pd.DataFrame(records) for records in games_analysis]
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [112], in <cell line: 2>()
#       1 # laod in games
# ----> 2 games = pd.read_json("../../testData/games.json", orient='records', lines=True)
#       3 with open("../../testData/games_analysis.json", "r") as file:
#       4     games_analysis = json.load(file)
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\io\json\_json.py:733, in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, numpy, precise_float, date_unit, encoding, encoding_errors, lines, chunksize, compression, nrows, storage_options)
#     730 if convert_axes is None and orient != "table":
#     731     convert_axes = True
# --> 733 json_reader = JsonReader(
#     734     path_or_buf,
#     735     orient=orient,
#     736     typ=typ,
#     737     dtype=dtype,
#     738     convert_axes=convert_axes,
#     739     convert_dates=convert_dates,
#     740     keep_default_dates=keep_default_dates,
#     741     numpy=numpy,
#     742     precise_float=precise_float,
#     743     date_unit=date_unit,
#     744     encoding=encoding,
#     745     lines=lines,
#     746     chunksize=chunksize,
#     747     compression=compression,
#     748     nrows=nrows,
#     749     storage_options=storage_options,
#     750     encoding_errors=encoding_errors,
#     751 )
#     753 if chunksize:
#     754     return json_reader
#
# File ~\anaconda3\lib\site-packages\pandas\io\json\_json.py:818, in JsonReader.__init__(self, filepath_or_buffer, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, numpy, precise_float, date_unit, encoding, lines, chunksize, compression, nrows, storage_options, encoding_errors)
#     815     if not self.lines:
#     816         raise ValueError("nrows can only be passed if lines=True")
# --> 818 data = self._get_data_from_filepath(filepath_or_buffer)
#     819 self.data = self._preprocess_data(data)
#
# File ~\anaconda3\lib\site-packages\pandas\io\json\_json.py:874, in JsonReader._get_data_from_filepath(self, filepath_or_buffer)
#     866     filepath_or_buffer = self.handles.handle
#     867 elif (
#     868     isinstance(filepath_or_buffer, str)
#     869     and filepath_or_buffer.lower().endswith(
#    (...)
#     872     and not file_exists(filepath_or_buffer)
#     873 ):
# --> 874     raise FileNotFoundError(f"File {filepath_or_buffer} does not exist")
#     876 return filepath_or_buffer
#
# FileNotFoundError: File ../../testData/games.json does not exist

# %%
eco = pd.read_csv("../../testData/ECO.csv")

# %%
games_analysis[0:30]
# Out:
# [    taken  invalid  evaluation  evaluation_change  accuracy  taken_score  \
#  0      []    False          22                 22       100            0
#  1      []    False          30                  8       100            0
#  2      []    False          33                  3       100            0
#  3      []    False          33                  0       100            0
#  4      []    False          30                 -3       100            0
#  5      []    False          31                  1       100            0
#  6     [n]    False           5                -26        75          300
#  7  [n, B]    False           7                  2       100            0
#  8  [n, B]    False         -14                -21       100            0
#  9  [n, B]    False          48                 62        50            0
#
#                                                   fen  \
#  0  rnbqkbnr/pppppppp/8/8/4P3/8/PPPP1PPP/RNBQKBNR ...
#  1  rnbqkbnr/pppp1ppp/8/4p3/4P3/8/PPPP1PPP/RNBQKBN...
#  2  rnbqkbnr/pppp1ppp/8/4p3/4P3/5N2/PPPP1PPP/RNBQK...
#  3  r1bqkbnr/pppp1ppp/2n5/4p3/4P3/5N2/PPPP1PPP/RNB...
#  4  r1bqkbnr/pppp1ppp/2n5/1B2p3/4P3/5N2/PPPP1PPP/R...
#  5  r1bqkbnr/1ppp1ppp/p1n5/1B2p3/4P3/5N2/PPPP1PPP/...
#  6  r1bqkbnr/1ppp1ppp/p1B5/4p3/4P3/5N2/PPPP1PPP/RN...
#  7  r1bqkbnr/1pp2ppp/p1p5/4p3/4P3/5N2/PPPP1PPP/RNB...
#  8  r1bqkbnr/1pp2ppp/p1p5/4p3/4P3/2N2N2/PPPP1PPP/R...
#  9  r1bqk1nr/1pp2ppp/p1pb4/4p3/4P3/2N2N2/PPPP1PPP/...
#
#                                 url last_move
#  0   https://lichess.org/R5xvWQmB#1      e2e4
#  1   https://lichess.org/R5xvWQmB#2      e7e5
#  2   https://lichess.org/R5xvWQmB#3      g1f3
#  3   https://lichess.org/R5xvWQmB#4      b8c6
#  4   https://lichess.org/R5xvWQmB#5      f1b5
#  5   https://lichess.org/R5xvWQmB#6      a7a6
#  6   https://lichess.org/R5xvWQmB#7      b5c6
#  7   https://lichess.org/R5xvWQmB#8      d7c6
#  8   https://lichess.org/R5xvWQmB#9      b1c3
#  9  https://lichess.org/R5xvWQmB#10      f8d6  ,
#    taken  invalid  evaluation  evaluation_change  accuracy  taken_score  \
#  0    []    False          23                -25       100            0
#  1    []    False          20                 -3       100            0
#  2    []    False        -216               -236         0            0
#  3   [P]    False        -208                  8       100         -100
#  4   [P]    False        -232                -24       100         -100
#  5   [P]    False        -227                  5       100         -100
#  6   [P]    False        -233                 -6       100         -100
#  7   [P]    False        -237                 -4       100         -100
#  8   [P]    False        -273                -36        75         -100
#  9   [P]    False        -261                 12       100         -100
#
#                                                   fen  \
#  0  rnbqkbnr/pppppppp/8/8/2P5/8/PP1PPPPP/RNBQKBNR ...
#  1  rnbqkbnr/pppp1ppp/8/4p3/2P5/8/PP1PPPPP/RNBQKBN...
#  2  rnbqkbnr/pppp1ppp/8/2P1p3/8/8/PP1PPPPP/RNBQKBN...
#  3  rnbqk1nr/pppp1ppp/8/2b1p3/8/8/PP1PPPPP/RNBQKBN...
#  4  rnbqk1nr/pppp1ppp/8/2b1p3/8/6P1/PP1PPP1P/RNBQK...
#  5  rnbqk2r/pppp1ppp/5n2/2b1p3/8/6P1/PP1PPP1P/RNBQ...
#  6  rnbqk2r/pppp1ppp/5n2/2b1p3/8/6P1/PP1PPPBP/RNBQ...
#  7  rnbqk2r/ppp2ppp/5n2/2bpp3/8/6P1/PP1PPPBP/RNBQK...
#  8  rnbqk2r/ppp2ppp/5n2/2bpp3/8/1P4P1/P2PPPBP/RNBQ...
#  9  rnbq1rk1/ppp2ppp/5n2/2bpp3/8/1P4P1/P2PPPBP/RNB...
#
#                                 url last_move
#  0   https://lichess.org/W4qIfyPj#1      c2c4
#  1   https://lichess.org/W4qIfyPj#2      e7e5
#  2   https://lichess.org/W4qIfyPj#3      c4c5
#  3   https://lichess.org/W4qIfyPj#4      f8c5
#  4   https://lichess.org/W4qIfyPj#5      g2g3
#  5   https://lichess.org/W4qIfyPj#6      g8f6
#  6   https://lichess.org/W4qIfyPj#7      f1g2
#  7   https://lichess.org/W4qIfyPj#8      d7d5
#  8   https://lichess.org/W4qIfyPj#9      b2b3
#  9  https://lichess.org/W4qIfyPj#10      e8g8  ,
#      taken  invalid  evaluation  evaluation_change  accuracy  taken_score  \
#  0      []    False          22                283         0            0
#  1      []    False          63                 41        75            0
#  2     [p]    False          58                 -5       100          100
#  3  [p, P]    False          66                  8       100            0
#  4  [p, P]    False          68                  2       100            0
#  5  [p, P]    False          63                 -5       100            0
#  6  [p, P]    False          57                 -6       100            0
#  7  [p, P]    False          65                  8       100            0
#  8  [p, P]    False          71                  6       100            0
#  9  [p, P]    False          76                  5       100            0
#
#                                                   fen  \
#  0  rnbqkbnr/pppppppp/8/8/4P3/8/PPPP1PPP/RNBQKBNR ...
#  1  rnbqkbnr/ppp1pppp/8/3p4/4P3/8/PPPP1PPP/RNBQKBN...
#  2  rnbqkbnr/ppp1pppp/8/3P4/8/8/PPPP1PPP/RNBQKBNR ...
#  3  rnb1kbnr/ppp1pppp/8/3q4/8/8/PPPP1PPP/RNBQKBNR ...
#  4  rnb1kbnr/ppp1pppp/8/3q4/8/2N5/PPPP1PPP/R1BQKBN...
#  5  rnbqkbnr/ppp1pppp/8/8/8/2N5/PPPP1PPP/R1BQKBNR ...
#  6  rnbqkbnr/ppp1pppp/8/8/8/2N2N2/PPPP1PPP/R1BQKB1...
#  7  rnbqkbnr/ppp1pp1p/6p1/8/8/2N2N2/PPPP1PPP/R1BQK...
#  8  rnbqkbnr/ppp1pp1p/6p1/8/3P4/2N2N2/PPP2PPP/R1BQ...
#  9  rnbqk1nr/ppp1ppbp/6p1/8/3P4/2N2N2/PPP2PPP/R1BQ...
#
#                                 url last_move
#  0   https://lichess.org/uAyyykrW#1      e2e4
#  1   https://lichess.org/uAyyykrW#2      d7d5
#  2   https://lichess.org/uAyyykrW#3      e4d5
#  3   https://lichess.org/uAyyykrW#4      d8d5
#  4   https://lichess.org/uAyyykrW#5      b1c3
#  5   https://lichess.org/uAyyykrW#6      d5d8
#  6   https://lichess.org/uAyyykrW#7      g1f3
#  7   https://lichess.org/uAyyykrW#8      g7g6
#  8   https://lichess.org/uAyyykrW#9      d2d4
#  9  https://lichess.org/uAyyykrW#10      f8g7  ,
#    taken  invalid  evaluation  evaluation_change  accuracy  taken_score  \
#  0    []    False          22                -54        50            0
#  1    []    False          30                  8       100            0
#  2    []    False          33                  3       100            0
#  3    []    False          33                  0       100            0
#  4    []    False          17                -16       100            0
#  5    []    False          25                  8       100            0
#  6    []    False         -32                -57        50            0
#  7   [P]    False         -15                 17       100         -100
#  8   [P]    False          -6                  9       100         -100
#  9   [P]    False           7                 13       100         -100
#
#                                                   fen  \
#  0  rnbqkbnr/pppppppp/8/8/4P3/8/PPPP1PPP/RNBQKBNR ...
#  1  rnbqkbnr/pppp1ppp/8/4p3/4P3/8/PPPP1PPP/RNBQKBN...
#  2  rnbqkbnr/pppp1ppp/8/4p3/4P3/5N2/PPPP1PPP/RNBQK...
#  3  r1bqkbnr/pppp1ppp/2n5/4p3/4P3/5N2/PPPP1PPP/RNB...
#  4  r1bqkbnr/pppp1ppp/2n5/4p3/2B1P3/5N2/PPPP1PPP/R...
#  5  r1bqk1nr/pppp1ppp/2n5/2b1p3/2B1P3/5N2/PPPP1PPP...
#  6  r1bqk1nr/pppp1ppp/2n5/2b1p3/1PB1P3/5N2/P1PP1PP...
#  7  r1bqk1nr/pppp1ppp/2n5/4p3/1bB1P3/5N2/P1PP1PPP/...
#  8  r1bqk1nr/pppp1ppp/2n5/4p3/1bB1P3/2P2N2/P2P1PPP...
#  9  r1bqk1nr/pppp1ppp/2n5/b3p3/2B1P3/2P2N2/P2P1PPP...
#
#                                 url last_move
#  0   https://lichess.org/vBCaaIq2#1      e2e4
#  1   https://lichess.org/vBCaaIq2#2      e7e5
#  2   https://lichess.org/vBCaaIq2#3      g1f3
#  3   https://lichess.org/vBCaaIq2#4      b8c6
#  4   https://lichess.org/vBCaaIq2#5      f1c4
#  5   https://lichess.org/vBCaaIq2#6      f8c5
#  6   https://lichess.org/vBCaaIq2#7      b2b4
#  7   https://lichess.org/vBCaaIq2#8      c5b4
#  8   https://lichess.org/vBCaaIq2#9      c2c3
#  9  https://lichess.org/vBCaaIq2#10      b4a5  ,
#      taken  invalid  evaluation  evaluation_change  accuracy  taken_score  \
#  0      []    False          22                 15       100            0
#  1      []    False          32                 10       100            0
#  2      []    False          25                 -7       100            0
#  3      []    False          49                 24       100            0
#  4      []    False          24                -25       100            0
#  5      []    False          23                 -1       100            0
#  6     [p]    False          28                  5       100          100
#  7  [p, P]    False          24                 -4       100            0
#  8  [p, P]    False          25                  1       100            0
#  9  [p, P]    False          25                  0       100            0
#
#                                                   fen  \
#  0  rnbqkbnr/pppppppp/8/8/4P3/8/PPPP1PPP/RNBQKBNR ...
#  1  rnbqkbnr/pp1ppppp/8/2p5/4P3/8/PPPP1PPP/RNBQKBN...
#  2  rnbqkbnr/pp1ppppp/8/2p5/4P3/5N2/PPPP1PPP/RNBQK...
#  3  rnbqkbnr/pp1p1ppp/4p3/2p5/4P3/5N2/PPPP1PPP/RNB...
#  4  rnbqkbnr/pp1p1ppp/4p3/2p5/4P3/2P2N2/PP1P1PPP/R...
#  5  rnbqkbnr/pp3ppp/4p3/2pp4/4P3/2P2N2/PP1P1PPP/RN...
#  6  rnbqkbnr/pp3ppp/4p3/2pP4/8/2P2N2/PP1P1PPP/RNBQ...
#  7  rnbqkbnr/pp3ppp/8/2pp4/8/2P2N2/PP1P1PPP/RNBQKB...
#  8  rnbqkbnr/pp3ppp/8/2pp4/3P4/2P2N2/PP3PPP/RNBQKB...
#  9  rnbqkb1r/pp3ppp/5n2/2pp4/3P4/2P2N2/PP3PPP/RNBQ...
#
#                                 url last_move
#  0   https://lichess.org/AAfUu8jz#1      e2e4
#  1   https://lichess.org/AAfUu8jz#2      c7c5
#  2   https://lichess.org/AAfUu8jz#3      g1f3
#  3   https://lichess.org/AAfUu8jz#4      e7e6
#  4   https://lichess.org/AAfUu8jz#5      c2c3
#  5   https://lichess.org/AAfUu8jz#6      d7d5
#  6   https://lichess.org/AAfUu8jz#7      e4d5
#  7   https://lichess.org/AAfUu8jz#8      e6d5
#  8   https://lichess.org/AAfUu8jz#9      d2d4
#  9  https://lichess.org/AAfUu8jz#10      g8f6  ,
#    taken  invalid  evaluation  evaluation_change  accuracy  taken_score  \
#  0    []    False          22                 -3       100            0
#  1    []    False          66                 44        75            0
#  2    []    False          22                -44        75            0
#  3    []    False         133                111         0            0
#  4    []    False         137                  4       100            0
#  5    []    False         144                  7       100            0
#  6    []    False         119                -25       100            0
#  7    []    False         164                 45        75            0
#  8    []    False         133                -31        75            0
#  9    []    False         151                 18       100            0
#
#                                                   fen  \
#  0  rnbqkbnr/pppppppp/8/8/4P3/8/PPPP1PPP/RNBQKBNR ...
#  1  rnbqkbnr/pppppp1p/6p1/8/4P3/8/PPPP1PPP/RNBQKBN...
#  2  rnbqkbnr/pppppp1p/6p1/8/4P3/2N5/PPPP1PPP/R1BQK...
#  3  rnbqkb1r/pppppp1p/6pn/8/4P3/2N5/PPPP1PPP/R1BQK...
#  4  rnbqkb1r/pppppp1p/6pn/8/3PP3/2N5/PPP2PPP/R1BQK...
#  5  rnbqk2r/ppppppbp/6pn/8/3PP3/2N5/PPP2PPP/R1BQKB...
#  6  rnbqk2r/ppppppbp/6pn/8/3PP3/2N2N2/PPP2PPP/R1BQ...
#  7  rnbqk2r/ppppp1bp/5ppn/8/3PP3/2N2N2/PPP2PPP/R1B...
#  8  rnbqk2r/ppppp1bp/5ppn/8/3PP3/2N2N2/PPP1BPPP/R1...
#  9  rnbqk2r/pppppnbp/5pp1/8/3PP3/2N2N2/PPP1BPPP/R1...
#
#                                 url last_move
#  0   https://lichess.org/BZZXNaeH#1      e2e4
#  1   https://lichess.org/BZZXNaeH#2      g7g6
#  2   https://lichess.org/BZZXNaeH#3      b1c3
#  3   https://lichess.org/BZZXNaeH#4      g8h6
#  4   https://lichess.org/BZZXNaeH#5      d2d4
#  5   https://lichess.org/BZZXNaeH#6      f8g7
#  6   https://lichess.org/BZZXNaeH#7      g1f3
#  7   https://lichess.org/BZZXNaeH#8      f7f6
#  8   https://lichess.org/BZZXNaeH#9      f1e2
#  9  https://lichess.org/BZZXNaeH#10      h6f7  ,
#    taken  invalid  evaluation  evaluation_change  accuracy  taken_score  \
#  0    []    False          31               -120         0            0
#  1    []    False          71                 40        75            0
#  2    []    False          51                -20       100            0
#  3    []    False          53                  2       100            0
#  4    []    False          45                 -8       100            0
#  5    []    False          58                 13       100            0
#  6    []    False          50                 -8       100            0
#  7    []    False          58                  8       100            0
#  8    []    False          45                -13       100            0
#  9    []    False          42                 -3       100            0
#
#                                                   fen  \
#  0  rnbqkbnr/pppppppp/8/8/3P4/8/PPP1PPPP/RNBQKBNR ...
#  1  rnbqkbnr/ppppp1pp/8/5p2/3P4/8/PPP1PPPP/RNBQKBN...
#  2  rnbqkbnr/ppppp1pp/8/5p2/3P1B2/8/PPP1PPPP/RN1QK...
#  3  rnbqkb1r/ppppp1pp/5n2/5p2/3P1B2/8/PPP1PPPP/RN1...
#  4  rnbqkb1r/ppppp1pp/5n2/5p2/3P1B2/5N2/PPP1PPPP/R...
#  5  rnbqkb1r/pppp2pp/4pn2/5p2/3P1B2/5N2/PPP1PPPP/R...
#  6  rnbqkb1r/pppp2pp/4pn2/5p2/3P1B2/4PN2/PPP2PPP/R...
#  7  rnbqkb1r/p1pp2pp/1p2pn2/5p2/3P1B2/4PN2/PPP2PPP...
#  8  rnbqkb1r/p1pp2pp/1p2pn2/5p2/3P1B2/3BPN2/PPP2PP...
#  9  rn1qkb1r/pbpp2pp/1p2pn2/5p2/3P1B2/3BPN2/PPP2PP...
#
#                                 url last_move
#  0   https://lichess.org/zGzfZ9ew#1      d2d4
#  1   https://lichess.org/zGzfZ9ew#2      f7f5
#  2   https://lichess.org/zGzfZ9ew#3      c1f4
#  3   https://lichess.org/zGzfZ9ew#4      g8f6
#  4   https://lichess.org/zGzfZ9ew#5      g1f3
#  5   https://lichess.org/zGzfZ9ew#6      e7e6
#  6   https://lichess.org/zGzfZ9ew#7      e2e3
#  7   https://lichess.org/zGzfZ9ew#8      b7b6
#  8   https://lichess.org/zGzfZ9ew#9      f1d3
#  9  https://lichess.org/zGzfZ9ew#10      c8b7  ,
#    taken  invalid  evaluation  evaluation_change  accuracy  taken_score  \
#  0    []    False          22                -20       100            0
#  1    []    False          30                  8       100            0
#  2    []    False          21                 -9       100            0
#  3    []    False          16                 -5       100            0
#  4    []    False          -9                -25       100            0
#  5    []    False         164                173         0            0
#  6   [p]    False         159                 -5       100          100
#  7   [p]    False         239                 80        25          100
#  8   [p]    False         235                 -4       100          100
#  9   [p]    False         241                  6       100          100
#
#                                                   fen  \
#  0  rnbqkbnr/pppppppp/8/8/4P3/8/PPPP1PPP/RNBQKBNR ...
#  1  rnbqkbnr/pppp1ppp/8/4p3/4P3/8/PPPP1PPP/RNBQKBN...
#  2  rnbqkbnr/pppp1ppp/8/4p3/4P3/2N5/PPPP1PPP/R1BQK...
#  3  rnbqkb1r/pppp1ppp/5n2/4p3/4P3/2N5/PPPP1PPP/R1B...
#  4  rnbqkb1r/pppp1ppp/5n2/4p3/4PP2/2N5/PPPP2PP/R1B...
#  5  r1bqkb1r/pppp1ppp/2n2n2/4p3/4PP2/2N5/PPPP2PP/R...
#  6  r1bqkb1r/pppp1ppp/2n2n2/4P3/4P3/2N5/PPPP2PP/R1...
#  7  r1bqkbnr/pppp1ppp/2n5/4P3/4P3/2N5/PPPP2PP/R1BQ...
#  8  r1bqkbnr/pppp1ppp/2n5/4P3/4P3/2N2N2/PPPP2PP/R1...
#  9  r1bqkbnr/ppp2ppp/2np4/4P3/4P3/2N2N2/PPPP2PP/R1...
#
#                                 url last_move
#  0   https://lichess.org/KTw23QRf#1      e2e4
#  1   https://lichess.org/KTw23QRf#2      e7e5
#  2   https://lichess.org/KTw23QRf#3      b1c3
#  3   https://lichess.org/KTw23QRf#4      g8f6
#  4   https://lichess.org/KTw23QRf#5      f2f4
#  5   https://lichess.org/KTw23QRf#6      b8c6
#  6   https://lichess.org/KTw23QRf#7      f4e5
#  7   https://lichess.org/KTw23QRf#8      f6g8
#  8   https://lichess.org/KTw23QRf#9      g1f3
#  9  https://lichess.org/KTw23QRf#10      d7d6  ,
#      taken  invalid  evaluation  evaluation_change  accuracy  taken_score  \
#  0      []    False          22               -219         0            0
#  1      []    False          63                 41        75            0
#  2     [p]    False          58                 -5       100          100
#  3  [p, P]    False          66                  8       100            0
#  4  [p, P]    False          68                  2       100            0
#  5  [p, P]    False          63                 -5       100            0
#  6  [p, P]    False          57                 -6       100            0
#  7  [p, P]    False          65                  8       100            0
#  8  [p, P]    False          58                 -7       100            0
#  9  [p, P]    False          71                 13       100            0
#
#                                                   fen  \
#  0  rnbqkbnr/pppppppp/8/8/4P3/8/PPPP1PPP/RNBQKBNR ...
#  1  rnbqkbnr/ppp1pppp/8/3p4/4P3/8/PPPP1PPP/RNBQKBN...
#  2  rnbqkbnr/ppp1pppp/8/3P4/8/8/PPPP1PPP/RNBQKBNR ...
#  3  rnb1kbnr/ppp1pppp/8/3q4/8/8/PPPP1PPP/RNBQKBNR ...
#  4  rnb1kbnr/ppp1pppp/8/3q4/8/2N5/PPPP1PPP/R1BQKBN...
#  5  rnbqkbnr/ppp1pppp/8/8/8/2N5/PPPP1PPP/R1BQKBNR ...
#  6  rnbqkbnr/ppp1pppp/8/8/8/2N2N2/PPPP1PPP/R1BQKB1...
#  7  rnbqkbnr/ppp1pp1p/6p1/8/8/2N2N2/PPPP1PPP/R1BQK...
#  8  rnbqkbnr/ppp1pp1p/6p1/8/2B5/2N2N2/PPPP1PPP/R1B...
#  9  rnbqk1nr/ppp1ppbp/6p1/8/2B5/2N2N2/PPPP1PPP/R1B...
#
#                                 url last_move
#  0   https://lichess.org/tJqJQE9l#1      e2e4
#  1   https://lichess.org/tJqJQE9l#2      d7d5
#  2   https://lichess.org/tJqJQE9l#3      e4d5
#  3   https://lichess.org/tJqJQE9l#4      d8d5
#  4   https://lichess.org/tJqJQE9l#5      b1c3
#  5   https://lichess.org/tJqJQE9l#6      d5d8
#  6   https://lichess.org/tJqJQE9l#7      g1f3
#  7   https://lichess.org/tJqJQE9l#8      g7g6
#  8   https://lichess.org/tJqJQE9l#9      f1c4
#  9  https://lichess.org/tJqJQE9l#10      f8g7  ,
#    taken  invalid  evaluation  evaluation_change  accuracy  taken_score  \
#  0    []    False          22                -49        75            0
#  1    []    False          30                  8       100            0
#  2    []    False          33                  3       100            0
#  3    []    False          33                  0       100            0
#  4    []    False          17                -16       100            0
#  5    []    False          25                  8       100            0
#  6    []    False          16                 -9       100            0
#  7    []    False          24                  8       100            0
#  8    []    False          15                 -9       100            0
#  9   [P]    False           6                 -9       100         -100
#
#                                                   fen  \
#  0  rnbqkbnr/pppppppp/8/8/4P3/8/PPPP1PPP/RNBQKBNR ...
#  1  rnbqkbnr/pppp1ppp/8/4p3/4P3/8/PPPP1PPP/RNBQKBN...
#  2  rnbqkbnr/pppp1ppp/8/4p3/4P3/5N2/PPPP1PPP/RNBQK...
#  3  r1bqkbnr/pppp1ppp/2n5/4p3/4P3/5N2/PPPP1PPP/RNB...
#  4  r1bqkbnr/pppp1ppp/2n5/4p3/2B1P3/5N2/PPPP1PPP/R...
#  5  r1bqk1nr/pppp1ppp/2n5/2b1p3/2B1P3/5N2/PPPP1PPP...
#  6  r1bqk1nr/pppp1ppp/2n5/2b1p3/2B1P3/2P2N2/PP1P1P...
#  7  r1bqk2r/pppp1ppp/2n2n2/2b1p3/2B1P3/2P2N2/PP1P1...
#  8  r1bqk2r/pppp1ppp/2n2n2/2b1p3/2BPP3/2P2N2/PP3PP...
#  9  r1bqk2r/pppp1ppp/2n2n2/2b5/2BpP3/2P2N2/PP3PPP/...
#
#                                 url last_move
#  0   https://lichess.org/KEkOpdsl#1      e2e4
#  1   https://lichess.org/KEkOpdsl#2      e7e5
#  2   https://lichess.org/KEkOpdsl#3      g1f3
#  3   https://lichess.org/KEkOpdsl#4      b8c6
#  4   https://lichess.org/KEkOpdsl#5      f1c4
#  5   https://lichess.org/KEkOpdsl#6      f8c5
#  6   https://lichess.org/KEkOpdsl#7      c2c3
#  7   https://lichess.org/KEkOpdsl#8      g8f6
#  8   https://lichess.org/KEkOpdsl#9      d2d4
#  9  https://lichess.org/KEkOpdsl#10      e5d4  ,
#    taken  invalid  evaluation  evaluation_change  accuracy  taken_score  \
#  0    []    False          31                 25       100            0
#  1    []    False          71                 40        75            0
#  2    []    False          51                -20       100            0
#  3    []    False          53                  2       100            0
#  4    []    False          55                  2       100            0
#  5    []    False          54                 -1       100            0
#  6    []    False          53                 -1       100            0
#  7    []    False          64                 11       100            0
#  8    []    False          51                -13       100            0
#  9    []    False          50                 -1       100            0
#
#                                                   fen  \
#  0  rnbqkbnr/pppppppp/8/8/3P4/8/PPP1PPPP/RNBQKBNR ...
#  1  rnbqkbnr/ppppp1pp/8/5p2/3P4/8/PPP1PPPP/RNBQKBN...
#  2  rnbqkbnr/ppppp1pp/8/5p2/3P1B2/8/PPP1PPPP/RN1QK...
#  3  rnbqkb1r/ppppp1pp/5n2/5p2/3P1B2/8/PPP1PPPP/RN1...
#  4  rnbqkb1r/ppppp1pp/5n2/5p2/3P1B2/4P3/PPP2PPP/RN...
#  5  rnbqkb1r/pppp2pp/4pn2/5p2/3P1B2/4P3/PPP2PPP/RN...
#  6  rnbqkb1r/pppp2pp/4pn2/5p2/3P1B2/4PN2/PPP2PPP/R...
#  7  rnbqk2r/ppppb1pp/4pn2/5p2/3P1B2/4PN2/PPP2PPP/R...
#  8  rnbqk2r/ppppb1pp/4pn2/5p2/3P1B2/3BPN2/PPP2PPP/...
#  9  rnbq1rk1/ppppb1pp/4pn2/5p2/3P1B2/3BPN2/PPP2PPP...
#
#                                 url last_move
#  0   https://lichess.org/nItMHMv2#1      d2d4
#  1   https://lichess.org/nItMHMv2#2      f7f5
#  2   https://lichess.org/nItMHMv2#3      c1f4
#  3   https://lichess.org/nItMHMv2#4      g8f6
#  4   https://lichess.org/nItMHMv2#5      e2e3
#  5   https://lichess.org/nItMHMv2#6      e7e6
#  6   https://lichess.org/nItMHMv2#7      g1f3
#  7   https://lichess.org/nItMHMv2#8      f8e7
#  8   https://lichess.org/nItMHMv2#9      f1d3
#  9  https://lichess.org/nItMHMv2#10      e8g8  ,
#      taken  invalid  evaluation  evaluation_change  accuracy  taken_score  \
#  0      []    False          22                -28        75            0
#  1      []    False          34                 12       100            0
#  2      []    False          22                -12       100            0
#  3      []    False          36                 14       100            0
#  4      []    False          17                -19       100            0
#  5      []    False         195                178         0            0
#  6     [p]    False          13               -182         0          100
#  7  [p, P]    False           9                 -4       100            0
#  8  [p, P]    False           7                 -2       100            0
#  9  [p, P]    False           9                  2       100            0
#
#                                                   fen  \
#  0  rnbqkbnr/pppppppp/8/8/4P3/8/PPPP1PPP/RNBQKBNR ...
#  1  rnbqkbnr/pppp1ppp/4p3/8/4P3/8/PPPP1PPP/RNBQKBN...
#  2  rnbqkbnr/pppp1ppp/4p3/8/4P3/2N5/PPPP1PPP/R1BQK...
#  3  rnbqkbnr/pp1p1ppp/4p3/2p5/4P3/2N5/PPPP1PPP/R1B...
#  4  rnbqkbnr/pp1p1ppp/4p3/2p5/3PP3/2N5/PPP2PPP/R1B...
#  5  r1bqkbnr/pp1p1ppp/2n1p3/2p5/3PP3/2N5/PPP2PPP/R...
#  6  r1bqkbnr/pp1p1ppp/2n1p3/2P5/4P3/2N5/PPP2PPP/R1...
#  7  r1bqk1nr/pp1p1ppp/2n1p3/2b5/4P3/2N5/PPP2PPP/R1...
#  8  r1bqk1nr/pp1p1ppp/2n1p3/2b5/4P3/2N2N2/PPP2PPP/...
#  9  r1bqk2r/pp1p1ppp/2n1pn2/2b5/4P3/2N2N2/PPP2PPP/...
#
#                                 url last_move
#  0   https://lichess.org/pI4tWzlI#1      e2e4
#  1   https://lichess.org/pI4tWzlI#2      e7e6
#  2   https://lichess.org/pI4tWzlI#3      b1c3
#  3   https://lichess.org/pI4tWzlI#4      c7c5
#  4   https://lichess.org/pI4tWzlI#5      d2d4
#  5   https://lichess.org/pI4tWzlI#6      b8c6
#  6   https://lichess.org/pI4tWzlI#7      d4c5
#  7   https://lichess.org/pI4tWzlI#8      f8c5
#  8   https://lichess.org/pI4tWzlI#9      g1f3
#  9  https://lichess.org/pI4tWzlI#10      g8f6  ,
#    taken  invalid  evaluation  evaluation_change  accuracy  taken_score  \
#  0    []    False          22                 13       100            0
#  1    []    False          30                  8       100            0
#  2    []    False           7                -23       100            0
#  3    []    False          25                 18       100            0
#  4    []    False          24                 -1       100            0
#  5    []    False          27                  3       100            0
#  6    []    False          14                -13       100            0
#  7    []    False          24                 10       100            0
#  8    []    False         -14                -38        75            0
#  9    []    False          13                 27        75            0
#
#                                                   fen  \
#  0  rnbqkbnr/pppppppp/8/8/4P3/8/PPPP1PPP/RNBQKBNR ...
#  1  rnbqkbnr/pppp1ppp/8/4p3/4P3/8/PPPP1PPP/RNBQKBN...
#  2  rnbqkbnr/pppp1ppp/8/4p3/2B1P3/8/PPPP1PPP/RNBQK...
#  3  r1bqkbnr/pppp1ppp/2n5/4p3/2B1P3/8/PPPP1PPP/RNB...
#  4  r1bqkbnr/pppp1ppp/2n5/4p3/2B1P3/3P4/PPP2PPP/RN...
#  5  r1bqk1nr/pppp1ppp/2n5/2b1p3/2B1P3/3P4/PPP2PPP/...
#  6  r1bqk1nr/pppp1ppp/2n5/2b1p3/2B1P3/2PP4/PP3PPP/...
#  7  r1bqk2r/pppp1ppp/2n2n2/2b1p3/2B1P3/2PP4/PP3PPP...
#  8  r1bqk2r/pppp1ppp/2n2n2/2b1p3/1PB1P3/2PP4/P4PPP...
#  9  r1bqk2r/pppp1ppp/1bn2n2/4p3/1PB1P3/2PP4/P4PPP/...
#
#                                 url last_move
#  0   https://lichess.org/t6kU1MF8#1      e2e4
#  1   https://lichess.org/t6kU1MF8#2      e7e5
#  2   https://lichess.org/t6kU1MF8#3      f1c4
#  3   https://lichess.org/t6kU1MF8#4      b8c6
#  4   https://lichess.org/t6kU1MF8#5      d2d3
#  5   https://lichess.org/t6kU1MF8#6      f8c5
#  6   https://lichess.org/t6kU1MF8#7      c2c3
#  7   https://lichess.org/t6kU1MF8#8      g8f6
#  8   https://lichess.org/t6kU1MF8#9      b2b4
#  9  https://lichess.org/t6kU1MF8#10      c5b6  ,
#    taken  invalid  evaluation  evaluation_change  accuracy  taken_score  \
#  0    []    False          22                  9       100            0
#  1    []    False          66                 44        75            0
#  2    []    False          22                -44        75            0
#  3    []    False          68                 46        75            0
#  4    []    False           0                -68        50            0
#  5    []    False          55                 55        50            0
#  6    []    False          50                 -5       100            0
#  7    []    False          63                 13       100            0
#  8    []    False          60                 -3       100            0
#  9    []    False         245                185         0            0
#
#                                                   fen  \
#  0  rnbqkbnr/pppppppp/8/8/4P3/8/PPPP1PPP/RNBQKBNR ...
#  1  rnbqkbnr/pppppp1p/6p1/8/4P3/8/PPPP1PPP/RNBQKBN...
#  2  rnbqkbnr/pppppp1p/6p1/8/4P3/2N5/PPPP1PPP/R1BQK...
#  3  rnbqk1nr/ppppppbp/6p1/8/4P3/2N5/PPPP1PPP/R1BQK...
#  4  rnbqk1nr/ppppppbp/6p1/8/2B1P3/2N5/PPPP1PPP/R1B...
#  5  rnbqk1nr/pp1pppbp/2p3p1/8/2B1P3/2N5/PPPP1PPP/R...
#  6  rnbqk1nr/pp1pppbp/2p3p1/8/2B1P3/2N2N2/PPPP1PPP...
#  7  rnbqk1nr/pp2ppbp/2pp2p1/8/2B1P3/2N2N2/PPPP1PPP...
#  8  rnbqk1nr/pp2ppbp/2pp2p1/8/2BPP3/2N2N2/PPP2PPP/...
#  9  rn1qk1nr/pp2ppbp/2pp2p1/8/2BPP1b1/2N2N2/PPP2PP...
#
#                                 url last_move
#  0   https://lichess.org/CiVvZQbP#1      e2e4
#  1   https://lichess.org/CiVvZQbP#2      g7g6
#  2   https://lichess.org/CiVvZQbP#3      b1c3
#  3   https://lichess.org/CiVvZQbP#4      f8g7
#  4   https://lichess.org/CiVvZQbP#5      f1c4
#  5   https://lichess.org/CiVvZQbP#6      c7c6
#  6   https://lichess.org/CiVvZQbP#7      g1f3
#  7   https://lichess.org/CiVvZQbP#8      d7d6
#  8   https://lichess.org/CiVvZQbP#9      d2d4
#  9  https://lichess.org/CiVvZQbP#10      c8g4  ,
#    taken  invalid  evaluation  evaluation_change  accuracy  taken_score  \
#  0    []    False          31               -214         0            0
#  1    []    False          71                 40        75            0
#  2    []    False          55                -16       100            0
#  3    []    False          54                 -1       100            0
#  4    []    False          50                 -4       100            0
#  5    []    False          57                  7       100            0
#  6    []    False          37                -20       100            0
#  7    []    False          57                 20       100            0
#  8    []    False          25                -32        75            0
#  9   [N]    False          33                  8       100         -300
#
#                                                   fen  \
#  0  rnbqkbnr/pppppppp/8/8/3P4/8/PPP1PPPP/RNBQKBNR ...
#  1  rnbqkbnr/ppppp1pp/8/5p2/3P4/8/PPP1PPPP/RNBQKBN...
#  2  rnbqkbnr/ppppp1pp/8/5p2/2PP4/8/PP2PPPP/RNBQKBN...
#  3  rnbqkb1r/ppppp1pp/5n2/5p2/2PP4/8/PP2PPPP/RNBQK...
#  4  rnbqkb1r/ppppp1pp/5n2/5p2/2PP4/2N5/PP2PPPP/R1B...
#  5  rnbqkb1r/pppp2pp/4pn2/5p2/2PP4/2N5/PP2PPPP/R1B...
#  6  rnbqkb1r/pppp2pp/4pn2/5p2/2PP4/2N1P3/PP3PPP/R1...
#  7  rnbqk2r/pppp2pp/4pn2/5p2/1bPP4/2N1P3/PP3PPP/R1...
#  8  rnbqk2r/pppp2pp/4pn2/5p2/1bPP4/2N1PN2/PP3PPP/R...
#  9  rnbqk2r/pppp2pp/4pn2/5p2/2PP4/2b1PN2/PP3PPP/R1...
#
#                                 url last_move
#  0   https://lichess.org/BcoQdj3B#1      d2d4
#  1   https://lichess.org/BcoQdj3B#2      f7f5
#  2   https://lichess.org/BcoQdj3B#3      c2c4
#  3   https://lichess.org/BcoQdj3B#4      g8f6
#  4   https://lichess.org/BcoQdj3B#5      b1c3
#  5   https://lichess.org/BcoQdj3B#6      e7e6
#  6   https://lichess.org/BcoQdj3B#7      e2e3
#  7   https://lichess.org/BcoQdj3B#8      f8b4
#  8   https://lichess.org/BcoQdj3B#9      g1f3
#  9  https://lichess.org/BcoQdj3B#10      b4c3  ,
#      taken  invalid  evaluation  evaluation_change  accuracy  taken_score  \
#  0      []    False          22                -11       100            0
#  1      []    False          63                 41        75            0
#  2     [p]    False          58                 -5       100          100
#  3  [p, P]    False          66                  8       100            0
#  4  [p, P]    False          68                  2       100            0
#  5  [p, P]    False          63                 -5       100            0
#  6  [p, P]    False          57                 -6       100            0
#  7  [p, P]    False          84                 27        75            0
#  8  [p, P]    False          70                -14       100            0
#  9  [p, P]    False         167                 97        25            0
#
#                                                   fen  \
#  0  rnbqkbnr/pppppppp/8/8/4P3/8/PPPP1PPP/RNBQKBNR ...
#  1  rnbqkbnr/ppp1pppp/8/3p4/4P3/8/PPPP1PPP/RNBQKBN...
#  2  rnbqkbnr/ppp1pppp/8/3P4/8/8/PPPP1PPP/RNBQKBNR ...
#  3  rnb1kbnr/ppp1pppp/8/3q4/8/8/PPPP1PPP/RNBQKBNR ...
#  4  rnb1kbnr/ppp1pppp/8/3q4/8/2N5/PPPP1PPP/R1BQKBN...
#  5  rnbqkbnr/ppp1pppp/8/8/8/2N5/PPPP1PPP/R1BQKBNR ...
#  6  rnbqkbnr/ppp1pppp/8/8/8/2N2N2/PPPP1PPP/R1BQKB1...
#  7  rn1qkbnr/ppp1pppp/8/8/6b1/2N2N2/PPPP1PPP/R1BQK...
#  8  rn1qkbnr/ppp1pppp/8/8/6b1/2N2N1P/PPPP1PP1/R1BQ...
#  9  rn1qkbnr/ppp1pppp/8/7b/8/2N2N1P/PPPP1PP1/R1BQK...
#
#                                 url last_move
#  0   https://lichess.org/bnSRav6u#1      e2e4
#  1   https://lichess.org/bnSRav6u#2      d7d5
#  2   https://lichess.org/bnSRav6u#3      e4d5
#  3   https://lichess.org/bnSRav6u#4      d8d5
#  4   https://lichess.org/bnSRav6u#5      b1c3
#  5   https://lichess.org/bnSRav6u#6      d5d8
#  6   https://lichess.org/bnSRav6u#7      g1f3
#  7   https://lichess.org/bnSRav6u#8      c8g4
#  8   https://lichess.org/bnSRav6u#9      h2h3
#  9  https://lichess.org/bnSRav6u#10      g4h5  ,
#      taken  invalid  evaluation  evaluation_change  accuracy  taken_score  \
#  0      []    False          22               -145         0            0
#  1      []    False          63                 41        75            0
#  2     [p]    False          58                 -5       100          100
#  3  [p, P]    False          66                  8       100            0
#  4  [p, P]    False          68                  2       100            0
#  5  [p, P]    False          63                 -5       100            0
#  6  [p, P]    False          57                 -6       100            0
#  7  [p, P]    False          94                 37        75            0
#  8  [p, P]    False          90                 -4       100            0
#  9  [p, P]    False          96                  6       100            0
#
#                                                   fen  \
#  0  rnbqkbnr/pppppppp/8/8/4P3/8/PPPP1PPP/RNBQKBNR ...
#  1  rnbqkbnr/ppp1pppp/8/3p4/4P3/8/PPPP1PPP/RNBQKBN...
#  2  rnbqkbnr/ppp1pppp/8/3P4/8/8/PPPP1PPP/RNBQKBNR ...
#  3  rnb1kbnr/ppp1pppp/8/3q4/8/8/PPPP1PPP/RNBQKBNR ...
#  4  rnb1kbnr/ppp1pppp/8/3q4/8/2N5/PPPP1PPP/R1BQKBN...
#  5  rnbqkbnr/ppp1pppp/8/8/8/2N5/PPPP1PPP/R1BQKBNR ...
#  6  rnbqkbnr/ppp1pppp/8/8/8/2N2N2/PPPP1PPP/R1BQKB1...
#  7  r1bqkbnr/ppp1pppp/2n5/8/8/2N2N2/PPPP1PPP/R1BQK...
#  8  r1bqkbnr/ppp1pppp/2n5/8/3P4/2N2N2/PPP2PPP/R1BQ...
#  9  r1bqkb1r/ppp1pppp/2n2n2/8/3P4/2N2N2/PPP2PPP/R1...
#
#                                 url last_move
#  0   https://lichess.org/sBmwb9C3#1      e2e4
#  1   https://lichess.org/sBmwb9C3#2      d7d5
#  2   https://lichess.org/sBmwb9C3#3      e4d5
#  3   https://lichess.org/sBmwb9C3#4      d8d5
#  4   https://lichess.org/sBmwb9C3#5      b1c3
#  5   https://lichess.org/sBmwb9C3#6      d5d8
#  6   https://lichess.org/sBmwb9C3#7      g1f3
#  7   https://lichess.org/sBmwb9C3#8      b8c6
#  8   https://lichess.org/sBmwb9C3#9      d2d4
#  9  https://lichess.org/sBmwb9C3#10      g8f6  ,
#    taken  invalid  evaluation  evaluation_change  accuracy  taken_score  \
#  0    []    False           2                -94        25            0
#  1    []    False           4                  2       100            0
#  2    []    False          -8                -12       100            0
#  3    []    False          -5                  3       100            0
#  4    []    False         -10                 -5       100            0
#  5    []    False          53                 63        50            0
#  6    []    False           0                -53        50            0
#  7    []    False           1                  1       100            0
#  8    []    False           0                 -1       100            0
#  9    []    False          -4                 -4       100            0
#
#                                                   fen  \
#  0  rnbqkbnr/pppppppp/8/8/8/3P4/PPP1PPPP/RNBQKBNR ...
#  1  rnbqkbnr/pppp1ppp/8/4p3/8/3P4/PPP1PPPP/RNBQKBN...
#  2  rnbqkbnr/pppp1ppp/8/4p3/4P3/3P4/PPP2PPP/RNBQKB...
#  3  r1bqkbnr/pppp1ppp/2n5/4p3/4P3/3P4/PPP2PPP/RNBQ...
#  4  r1bqkbnr/pppp1ppp/2n5/4p3/4P3/3P1N2/PPP2PPP/RN...
#  5  r1bqk1nr/pppp1ppp/2n5/2b1p3/4P3/3P1N2/PPP2PPP/...
#  6  r1bqk1nr/pppp1ppp/2n5/2b1p3/4P3/3P1N2/PPP1BPPP...
#  7  r1bqk2r/pppp1ppp/2n2n2/2b1p3/4P3/3P1N2/PPP1BPP...
#  8  r1bqk2r/pppp1ppp/2n2n2/2b1p3/4P3/3P1N2/PPP1BPP...
#  9  r1bqk2r/ppp2ppp/2np1n2/2b1p3/4P3/3P1N2/PPP1BPP...
#
#                                 url last_move
#  0   https://lichess.org/KuRI2yIi#1      d2d3
#  1   https://lichess.org/KuRI2yIi#2      e7e5
#  2   https://lichess.org/KuRI2yIi#3      e2e4
#  3   https://lichess.org/KuRI2yIi#4      b8c6
#  4   https://lichess.org/KuRI2yIi#5      g1f3
#  5   https://lichess.org/KuRI2yIi#6      f8c5
#  6   https://lichess.org/KuRI2yIi#7      f1e2
#  7   https://lichess.org/KuRI2yIi#8      g8f6
#  8   https://lichess.org/KuRI2yIi#9      e1g1
#  9  https://lichess.org/KuRI2yIi#10      d7d6  ,
#    taken  invalid  evaluation  evaluation_change  accuracy  taken_score  \
#  0    []    False          22                 26        75            0
#  1    []    False          30                  8       100            0
#  2    []    False         -49                -79        25            0
#  3   [P]    False         -43                  6       100         -100
#  4   [P]    False         -80                -37        75         -100
#  5   [P]    False          89                169         0         -100
#  6   [P]    False         -83               -172         0         -100
#  7   [P]    False         125                208         0         -100
#  8   [P]    False          86                -39        75         -100
#  9   [P]    False         244                158         0         -100
#
#                                                   fen  \
#  0  rnbqkbnr/pppppppp/8/8/4P3/8/PPPP1PPP/RNBQKBNR ...
#  1  rnbqkbnr/pppp1ppp/8/4p3/4P3/8/PPPP1PPP/RNBQKBN...
#  2  rnbqkbnr/pppp1ppp/8/4p3/4PP2/8/PPPP2PP/RNBQKBN...
#  3  rnbqkbnr/pppp1ppp/8/8/4Pp2/8/PPPP2PP/RNBQKBNR ...
#  4  rnbqkbnr/pppp1ppp/8/8/3PPp2/8/PPP3PP/RNBQKBNR ...
#  5  rnbqkbnr/pppp1p1p/8/6p1/3PPp2/8/PPP3PP/RNBQKBN...
#  6  rnbqkbnr/pppp1p1p/8/6p1/3PPp2/5N2/PPP3PP/RNBQK...
#  7  rnbqk1nr/ppppbp1p/8/6p1/3PPp2/5N2/PPP3PP/RNBQK...
#  8  rnbqk1nr/ppppbp1p/8/6p1/3PPp2/2N2N2/PPP3PP/R1B...
#  9  rnbqk1nr/p1ppbp1p/1p6/6p1/3PPp2/2N2N2/PPP3PP/R...
#
#                                 url last_move
#  0   https://lichess.org/eT7BiAGe#1      e2e4
#  1   https://lichess.org/eT7BiAGe#2      e7e5
#  2   https://lichess.org/eT7BiAGe#3      f2f4
#  3   https://lichess.org/eT7BiAGe#4      e5f4
#  4   https://lichess.org/eT7BiAGe#5      d2d4
#  5   https://lichess.org/eT7BiAGe#6      g7g5
#  6   https://lichess.org/eT7BiAGe#7      g1f3
#  7   https://lichess.org/eT7BiAGe#8      f8e7
#  8   https://lichess.org/eT7BiAGe#9      b1c3
#  9  https://lichess.org/eT7BiAGe#10      b7b6  ,
#      taken  invalid  evaluation  evaluation_change  accuracy  taken_score  \
#  0      []    False          22               -222         0            0
#  1      []    False          30                  8       100            0
#  2      []    False          21                 -9       100            0
#  3      []    False         147                126         0            0
#  4      []    False         113                -34        75            0
#  5      []    False         155                 42        75            0
#  6      []    False          96                -59        50            0
#  7     [P]    False         170                 74        50         -100
#  8  [P, p]    False          62               -108         0            0
#  9  [P, p]    False          61                 -1       100            0
#
#                                                   fen  \
#  0  rnbqkbnr/pppppppp/8/8/4P3/8/PPPP1PPP/RNBQKBNR ...
#  1  rnbqkbnr/pppp1ppp/8/4p3/4P3/8/PPPP1PPP/RNBQKBN...
#  2  rnbqkbnr/pppp1ppp/8/4p3/4P3/2N5/PPPP1PPP/R1BQK...
#  3  rnbqkbnr/pppp2pp/5p2/4p3/4P3/2N5/PPPP1PPP/R1BQ...
#  4  rnbqkbnr/pppp2pp/5p2/4p3/4P3/2N2N2/PPPP1PPP/R1...
#  5  rnbqk1nr/pppp2pp/5p2/4p3/1b2P3/2N2N2/PPPP1PPP/...
#  6  rnbqk1nr/pppp2pp/5p2/4p3/1b1PP3/2N2N2/PPP2PPP/...
#  7  rnbqk1nr/pppp2pp/5p2/8/1b1pP3/2N2N2/PPP2PPP/R1...
#  8  rnbqk1nr/pppp2pp/5p2/8/1b1QP3/2N2N2/PPP2PPP/R1...
#  9  r1bqk1nr/pppp2pp/2n2p2/8/1b1QP3/2N2N2/PPP2PPP/...
#
#                                 url last_move
#  0   https://lichess.org/RTmLcPYA#1      e2e4
#  1   https://lichess.org/RTmLcPYA#2      e7e5
#  2   https://lichess.org/RTmLcPYA#3      b1c3
#  3   https://lichess.org/RTmLcPYA#4      f7f6
#  4   https://lichess.org/RTmLcPYA#5      g1f3
#  5   https://lichess.org/RTmLcPYA#6      f8b4
#  6   https://lichess.org/RTmLcPYA#7      d2d4
#  7   https://lichess.org/RTmLcPYA#8      e5d4
#  8   https://lichess.org/RTmLcPYA#9      d1d4
#  9  https://lichess.org/RTmLcPYA#10      b8c6  ,
#    taken  invalid  evaluation  evaluation_change  accuracy  taken_score  \
#  0    []    False          22                -39        75            0
#  1    []    False          30                  8       100            0
#  2    []    False          21                 -9       100            0
#  3    []    False         153                132         0            0
#  4   [p]    False         181                 28        75          100
#  5   [p]    False         175                 -6       100          100
#  6   [p]    False          50               -125         0          100
#  7   [p]    False         145                 95        25          100
#  8   [p]    False         -32               -177         0          100
#  9   [p]    False         127                159         0          100
#
#                                                   fen  \
#  0  rnbqkbnr/pppppppp/8/8/4P3/8/PPPP1PPP/RNBQKBNR ...
#  1  rnbqkbnr/pppp1ppp/8/4p3/4P3/8/PPPP1PPP/RNBQKBN...
#  2  rnbqkbnr/pppp1ppp/8/4p3/4P3/2N5/PPPP1PPP/R1BQK...
#  3  rnbqkbnr/pppp2pp/8/4pp2/4P3/2N5/PPPP1PPP/R1BQK...
#  4  rnbqkbnr/pppp2pp/8/4pP2/8/2N5/PPPP1PPP/R1BQKBN...
#  5  rnbqkb1r/pppp2pp/5n2/4pP2/8/2N5/PPPP1PPP/R1BQK...
#  6  rnbqkb1r/pppp2pp/5n2/4pP2/2B5/2N5/PPPP1PPP/R1B...
#  7  rnbqkb1r/ppp3pp/5n2/3ppP2/2B5/2N5/PPPP1PPP/R1B...
#  8  rnbqkb1r/ppp3pp/5n2/3ppP2/8/1BN5/PPPP1PPP/R1BQ...
#  9  rnbqkb1r/pp4pp/5n2/2pppP2/8/1BN5/PPPP1PPP/R1BQ...
#
#                                 url last_move
#  0   https://lichess.org/UZfTONoz#1      e2e4
#  1   https://lichess.org/UZfTONoz#2      e7e5
#  2   https://lichess.org/UZfTONoz#3      b1c3
#  3   https://lichess.org/UZfTONoz#4      f7f5
#  4   https://lichess.org/UZfTONoz#5      e4f5
#  5   https://lichess.org/UZfTONoz#6      g8f6
#  6   https://lichess.org/UZfTONoz#7      f1c4
#  7   https://lichess.org/UZfTONoz#8      d7d5
#  8   https://lichess.org/UZfTONoz#9      c4b3
#  9  https://lichess.org/UZfTONoz#10      c7c5  ,
#    taken  invalid  evaluation  evaluation_change  accuracy  taken_score  \
#  0    []    False          22               -105         0            0
#  1    []    False          30                  8       100            0
#  2    []    False          21                 -9       100            0
#  3    []    False          16                 -5       100            0
#  4    []    False          -9                -25       100            0
#  5   [P]    False          78                 87        25         -100
#  6   [P]    False          66                -12       100         -100
#  7   [P]    False          64                 -2       100         -100
#  8   [P]    False          74                 10       100         -100
#  9   [P]    False          62                -12       100         -100
#
#                                                   fen  \
#  0  rnbqkbnr/pppppppp/8/8/4P3/8/PPPP1PPP/RNBQKBNR ...
#  1  rnbqkbnr/pppp1ppp/8/4p3/4P3/8/PPPP1PPP/RNBQKBN...
#  2  rnbqkbnr/pppp1ppp/8/4p3/4P3/2N5/PPPP1PPP/R1BQK...
#  3  rnbqkb1r/pppp1ppp/5n2/4p3/4P3/2N5/PPPP1PPP/R1B...
#  4  rnbqkb1r/pppp1ppp/5n2/4p3/4PP2/2N5/PPPP2PP/R1B...
#  5  rnbqkb1r/pppp1ppp/5n2/8/4Pp2/2N5/PPPP2PP/R1BQK...
#  6  rnbqkb1r/pppp1ppp/5n2/4P3/5p2/2N5/PPPP2PP/R1BQ...
#  7  rnbqkbnr/pppp1ppp/8/4P3/5p2/2N5/PPPP2PP/R1BQKB...
#  8  rnbqkbnr/pppp1ppp/8/4P3/5p2/2N2N2/PPPP2PP/R1BQ...
#  9  rnbqkbnr/ppp2ppp/3p4/4P3/5p2/2N2N2/PPPP2PP/R1B...
#
#                                 url last_move
#  0   https://lichess.org/lCJ2omTj#1      e2e4
#  1   https://lichess.org/lCJ2omTj#2      e7e5
#  2   https://lichess.org/lCJ2omTj#3      b1c3
#  3   https://lichess.org/lCJ2omTj#4      g8f6
#  4   https://lichess.org/lCJ2omTj#5      f2f4
#  5   https://lichess.org/lCJ2omTj#6      e5f4
#  6   https://lichess.org/lCJ2omTj#7      e4e5
#  7   https://lichess.org/lCJ2omTj#8      f6g8
#  8   https://lichess.org/lCJ2omTj#9      g1f3
#  9  https://lichess.org/lCJ2omTj#10      d7d6  ,
#    taken  invalid  evaluation  evaluation_change  accuracy  taken_score  \
#  0    []    False          22                -40        75            0
#  1    []    False          30                  8       100            0
#  2    []    False          -8                -38        75            0
#  3    []    False          -5                  3       100            0
#  4    []    False          -4                  1       100            0
#  5    []    False           8                 12       100            0
#  6    []    False         -22                -30        75            0
#  7    []    False         -17                  5       100            0
#  8    []    False         -66                -49        75            0
#  9    []    False         -17                 49        75            0
#
#                                                   fen  \
#  0  rnbqkbnr/pppppppp/8/8/4P3/8/PPPP1PPP/RNBQKBNR ...
#  1  rnbqkbnr/pppp1ppp/8/4p3/4P3/8/PPPP1PPP/RNBQKBN...
#  2  rnbqkbnr/pppp1ppp/8/4p3/4P3/3P4/PPP2PPP/RNBQKB...
#  3  r1bqkbnr/pppp1ppp/2n5/4p3/4P3/3P4/PPP2PPP/RNBQ...
#  4  r1bqkbnr/pppp1ppp/2n5/4p3/4P3/2NP4/PPP2PPP/R1B...
#  5  r1bqk1nr/pppp1ppp/2n5/2b1p3/4P3/2NP4/PPP2PPP/R...
#  6  r1bqk1nr/pppp1ppp/2n5/2b1p3/4P3/P1NP4/1PP2PPP/...
#  7  r1bqk2r/pppp1ppp/2n2n2/2b1p3/4P3/P1NP4/1PP2PPP...
#  8  r1bqk2r/pppp1ppp/2n2n2/2b1p3/4P3/P1NP3P/1PP2PP...
#  9  r1bqk2r/ppp2ppp/2np1n2/2b1p3/4P3/P1NP3P/1PP2PP...
#
#                                 url last_move
#  0   https://lichess.org/yQhxpKiF#1      e2e4
#  1   https://lichess.org/yQhxpKiF#2      e7e5
#  2   https://lichess.org/yQhxpKiF#3      d2d3
#  3   https://lichess.org/yQhxpKiF#4      b8c6
#  4   https://lichess.org/yQhxpKiF#5      b1c3
#  5   https://lichess.org/yQhxpKiF#6      f8c5
#  6   https://lichess.org/yQhxpKiF#7      a2a3
#  7   https://lichess.org/yQhxpKiF#8      g8f6
#  8   https://lichess.org/yQhxpKiF#9      h2h3
#  9  https://lichess.org/yQhxpKiF#10      d7d6  ,
#      taken  invalid  evaluation  evaluation_change  accuracy  taken_score  \
#  0      []    False          22                 39        75            0
#  1      []    False          35                 13       100            0
#  2      []    False          27                 -8       100            0
#  3      []    False          30                  3       100            0
#  4     [p]    False           1                -29        75          100
#  5  [p, P]    False          -4                 -5       100            0
#  6  [p, P]    False           0                  4       100            0
#  7  [p, P]    False           8                  8       100            0
#  8  [p, P]    False          -8                -16       100            0
#  9  [p, P]    False          28                 36        75            0
#
#                                                   fen  \
#  0  rnbqkbnr/pppppppp/8/8/4P3/8/PPPP1PPP/RNBQKBNR ...
#  1  rnbqkbnr/pp1ppppp/2p5/8/4P3/8/PPPP1PPP/RNBQKBN...
#  2  rnbqkbnr/pp1ppppp/2p5/8/4P3/2N5/PPPP1PPP/R1BQK...
#  3  rnbqkbnr/pp2pppp/2p5/3p4/4P3/2N5/PPPP1PPP/R1BQ...
#  4  rnbqkbnr/pp2pppp/2p5/3P4/8/2N5/PPPP1PPP/R1BQKB...
#  5  rnbqkbnr/pp2pppp/8/3p4/8/2N5/PPPP1PPP/R1BQKBNR...
#  6  rnbqkbnr/pp2pppp/8/3p4/3P4/2N5/PPP2PPP/R1BQKBN...
#  7  rn1qkbnr/pp2pppp/8/3p1b2/3P4/2N5/PPP2PPP/R1BQK...
#  8  rn1qkbnr/pp2pppp/8/3p1b2/3P4/2N2N2/PPP2PPP/R1B...
#  9  rn1qkbnr/pp3ppp/4p3/3p1b2/3P4/2N2N2/PPP2PPP/R1...
#
#                                 url last_move
#  0   https://lichess.org/Bwqa16Q8#1      e2e4
#  1   https://lichess.org/Bwqa16Q8#2      c7c6
#  2   https://lichess.org/Bwqa16Q8#3      b1c3
#  3   https://lichess.org/Bwqa16Q8#4      d7d5
#  4   https://lichess.org/Bwqa16Q8#5      e4d5
#  5   https://lichess.org/Bwqa16Q8#6      c6d5
#  6   https://lichess.org/Bwqa16Q8#7      d2d4
#  7   https://lichess.org/Bwqa16Q8#8      c8f5
#  8   https://lichess.org/Bwqa16Q8#9      g1f3
#  9  https://lichess.org/Bwqa16Q8#10      e7e6  ,
#    taken  invalid  evaluation  evaluation_change  accuracy  taken_score  \
#  0    []    False          22                 -6       100            0
#  1    []    False          30                  8       100            0
#  2    []    False         -49                -79        25            0
#  3   [P]    False         -43                  6       100         -100
#  4   [P]    False         -66                -23       100         -100
#  5   [P]    False         -70                 -4       100         -100
#  6   [P]    False        -108                -38        75         -100
#  7   [P]    False         -97                 11       100         -100
#  8   [P]    False         -84                 13       100         -100
#  9   [P]    False         123                207         0         -100
#
#                                                   fen  \
#  0  rnbqkbnr/pppppppp/8/8/4P3/8/PPPP1PPP/RNBQKBNR ...
#  1  rnbqkbnr/pppp1ppp/8/4p3/4P3/8/PPPP1PPP/RNBQKBN...
#  2  rnbqkbnr/pppp1ppp/8/4p3/4PP2/8/PPPP2PP/RNBQKBN...
#  3  rnbqkbnr/pppp1ppp/8/8/4Pp2/8/PPPP2PP/RNBQKBNR ...
#  4  rnbqkbnr/pppp1ppp/8/8/4Pp2/5N2/PPPP2PP/RNBQKB1...
#  5  rnbqkbnr/pppp1p1p/8/6p1/4Pp2/5N2/PPPP2PP/RNBQK...
#  6  rnbqkbnr/pppp1p1p/8/6p1/2B1Pp2/5N2/PPPP2PP/RNB...
#  7  r1bqkbnr/pppp1p1p/2n5/6p1/2B1Pp2/5N2/PPPP2PP/R...
#  8  r1bqkbnr/pppp1p1p/2n5/6p1/2BPPp2/5N2/PPP3PP/RN...
#  9  r1bqk1nr/pppp1p1p/2n4b/6p1/2BPPp2/5N2/PPP3PP/R...
#
#                                 url last_move
#  0   https://lichess.org/4u0ZZXT8#1      e2e4
#  1   https://lichess.org/4u0ZZXT8#2      e7e5
#  2   https://lichess.org/4u0ZZXT8#3      f2f4
#  3   https://lichess.org/4u0ZZXT8#4      e5f4
#  4   https://lichess.org/4u0ZZXT8#5      g1f3
#  5   https://lichess.org/4u0ZZXT8#6      g7g5
#  6   https://lichess.org/4u0ZZXT8#7      f1c4
#  7   https://lichess.org/4u0ZZXT8#8      b8c6
#  8   https://lichess.org/4u0ZZXT8#9      d2d4
#  9  https://lichess.org/4u0ZZXT8#10      f8h6  ,
#    taken  invalid  evaluation  evaluation_change  accuracy  taken_score  \
#  0    []    False          22               -101         0            0
#  1    []    False          30                  8       100            0
#  2    []    False          33                  3       100            0
#  3    []    False          33                  0       100            0
#  4    []    False          30                 -3       100            0
#  5    []    False          31                  1       100            0
#  6    []    False          39                  8       100            0
#  7    []    False          32                 -7       100            0
#  8    []    False           9                -23       100            0
#  9    []    False         107                 98        25            0
#
#                                                   fen  \
#  0  rnbqkbnr/pppppppp/8/8/4P3/8/PPPP1PPP/RNBQKBNR ...
#  1  rnbqkbnr/pppp1ppp/8/4p3/4P3/8/PPPP1PPP/RNBQKBN...
#  2  rnbqkbnr/pppp1ppp/8/4p3/4P3/5N2/PPPP1PPP/RNBQK...
#  3  r1bqkbnr/pppp1ppp/2n5/4p3/4P3/5N2/PPPP1PPP/RNB...
#  4  r1bqkbnr/pppp1ppp/2n5/1B2p3/4P3/5N2/PPPP1PPP/R...
#  5  r1bqkbnr/1ppp1ppp/p1n5/1B2p3/4P3/5N2/PPPP1PPP/...
#  6  r1bqkbnr/1ppp1ppp/p1n5/4p3/B3P3/5N2/PPPP1PPP/R...
#  7  r1bqkb1r/1ppp1ppp/p1n2n2/4p3/B3P3/5N2/PPPP1PPP...
#  8  r1bqkb1r/1ppp1ppp/p1n2n2/4p3/B3P3/3P1N2/PPP2PP...
#  9  r1bqk2r/1pppbppp/p1n2n2/4p3/B3P3/3P1N2/PPP2PPP...
#
#                                 url last_move
#  0   https://lichess.org/Z6GsD7DN#1      e2e4
#  1   https://lichess.org/Z6GsD7DN#2      e7e5
#  2   https://lichess.org/Z6GsD7DN#3      g1f3
#  3   https://lichess.org/Z6GsD7DN#4      b8c6
#  4   https://lichess.org/Z6GsD7DN#5      f1b5
#  5   https://lichess.org/Z6GsD7DN#6      a7a6
#  6   https://lichess.org/Z6GsD7DN#7      b5a4
#  7   https://lichess.org/Z6GsD7DN#8      g8f6
#  8   https://lichess.org/Z6GsD7DN#9      d2d3
#  9  https://lichess.org/Z6GsD7DN#10      f8e7  ,
#      taken  invalid  evaluation  evaluation_change  accuracy  taken_score  \
#  0      []    False          22                -85        25            0
#  1      []    False          30                  8       100            0
#  2      []    False           7                -23       100            0
#  3      []    False          25                 18       100            0
#  4      []    False          17                 -8       100            0
#  5      []    False          25                  8       100            0
#  6     [p]    False        -299               -324         0          100
#  7  [p, N]    False        -282                 17       100         -200
#  8  [p, N]    False        -371                -89        25         -200
#  9  [p, N]    False         250                621         0         -200
#
#                                                   fen  \
#  0  rnbqkbnr/pppppppp/8/8/4P3/8/PPPP1PPP/RNBQKBNR ...
#  1  rnbqkbnr/pppp1ppp/8/4p3/4P3/8/PPPP1PPP/RNBQKBN...
#  2  rnbqkbnr/pppp1ppp/8/4p3/2B1P3/8/PPPP1PPP/RNBQK...
#  3  r1bqkbnr/pppp1ppp/2n5/4p3/2B1P3/8/PPPP1PPP/RNB...
#  4  r1bqkbnr/pppp1ppp/2n5/4p3/2B1P3/5N2/PPPP1PPP/R...
#  5  r1bqk1nr/pppp1ppp/2n5/2b1p3/2B1P3/5N2/PPPP1PPP...
#  6  r1bqk1nr/pppp1ppp/2n5/2b1N3/2B1P3/8/PPPP1PPP/R...
#  7  r1bqk1nr/pppp1ppp/8/2b1n3/2B1P3/8/PPPP1PPP/RNB...
#  8  r1bqk1nr/pppp1ppp/8/2b1n3/2BPP3/8/PPP2PPP/RNBQ...
#  9  r1bqk1nr/pppp1ppp/3b4/4n3/2BPP3/8/PPP2PPP/RNBQ...
#
#                                 url last_move
#  0   https://lichess.org/pPDQft7I#1      e2e4
#  1   https://lichess.org/pPDQft7I#2      e7e5
#  2   https://lichess.org/pPDQft7I#3      f1c4
#  3   https://lichess.org/pPDQft7I#4      b8c6
#  4   https://lichess.org/pPDQft7I#5      g1f3
#  5   https://lichess.org/pPDQft7I#6      f8c5
#  6   https://lichess.org/pPDQft7I#7      f3e5
#  7   https://lichess.org/pPDQft7I#8      c6e5
#  8   https://lichess.org/pPDQft7I#9      d2d4
#  9  https://lichess.org/pPDQft7I#10      c5d6  ,
#    taken  invalid  evaluation  evaluation_change  accuracy  taken_score  \
#  0    []    False          22               -228         0            0
#  1    []    False          32                 10       100            0
#  2    []    False          20                -12       100            0
#  3    []    False          33                 13       100            0
#  4    []    False         -16                -49        75            0
#  5    []    False          -5                 11       100            0
#  6    []    False         -10                 -5       100            0
#  7    []    False          10                 20       100            0
#  8    []    False         -15                -25       100            0
#  9    []    False         -14                  1       100            0
#
#                                                   fen  \
#  0  rnbqkbnr/pppppppp/8/8/4P3/8/PPPP1PPP/RNBQKBNR ...
#  1  rnbqkbnr/pp1ppppp/8/2p5/4P3/8/PPPP1PPP/RNBQKBN...
#  2  rnbqkbnr/pp1ppppp/8/2p5/4P3/2P5/PP1P1PPP/RNBQK...
#  3  rnbqkbnr/pp2pppp/8/2pp4/4P3/2P5/PP1P1PPP/RNBQK...
#  4  rnbqkbnr/pp2pppp/8/2ppP3/8/2P5/PP1P1PPP/RNBQKB...
#  5  rn1qkbnr/pp2pppp/8/2ppPb2/8/2P5/PP1P1PPP/RNBQK...
#  6  rn1qkbnr/pp2pppp/8/2ppPb2/3P4/2P5/PP3PPP/RNBQK...
#  7  r2qkbnr/pp2pppp/2n5/2ppPb2/3P4/2P5/PP3PPP/RNBQ...
#  8  r2qkbnr/pp2pppp/2n5/2ppPb2/3P4/2P2N2/PP3PPP/RN...
#  9  r2qkbnr/pp3ppp/2n1p3/2ppPb2/3P4/2P2N2/PP3PPP/R...
#
#                                 url last_move
#  0   https://lichess.org/XWnsEiqv#1      e2e4
#  1   https://lichess.org/XWnsEiqv#2      c7c5
#  2   https://lichess.org/XWnsEiqv#3      c2c3
#  3   https://lichess.org/XWnsEiqv#4      d7d5
#  4   https://lichess.org/XWnsEiqv#5      e4e5
#  5   https://lichess.org/XWnsEiqv#6      c8f5
#  6   https://lichess.org/XWnsEiqv#7      d2d4
#  7   https://lichess.org/XWnsEiqv#8      b8c6
#  8   https://lichess.org/XWnsEiqv#9      g1f3
#  9  https://lichess.org/XWnsEiqv#10      e7e6  ,
#    taken  invalid  evaluation  evaluation_change  accuracy  taken_score  \
#  0    []    False          22                 36        75            0
#  1    []    False          66                 44        75            0
#  2    []    False          22                -44        75            0
#  3    []    False          68                 46        75            0
#  4    []    False          55                -13       100            0
#  5    []    False         128                 73        50            0
#  6    []    False         134                  6       100            0
#  7    []    False         376                242         0            0
#  8    []    False         263               -113         0            0
#  9    []    False         308                 45        75            0
#
#                                                   fen  \
#  0  rnbqkbnr/pppppppp/8/8/4P3/8/PPPP1PPP/RNBQKBNR ...
#  1  rnbqkbnr/pppppp1p/6p1/8/4P3/8/PPPP1PPP/RNBQKBN...
#  2  rnbqkbnr/pppppp1p/6p1/8/4P3/2N5/PPPP1PPP/R1BQK...
#  3  rnbqk1nr/ppppppbp/6p1/8/4P3/2N5/PPPP1PPP/R1BQK...
#  4  rnbqk1nr/ppppppbp/6p1/8/3PP3/2N5/PPP2PPP/R1BQK...
#  5  rnbqk2r/ppppppbp/5np1/8/3PP3/2N5/PPP2PPP/R1BQK...
#  6  rnbqk2r/ppppppbp/5np1/4P3/3P4/2N5/PPP2PPP/R1BQ...
#  7  rnbqk2r/ppppppbp/6p1/4P2n/3P4/2N5/PPP2PPP/R1BQ...
#  8  rnbqk2r/ppppppbp/6p1/4P2n/3P4/2N5/PPP1BPPP/R1B...
#  9  rnbqk2r/ppp1ppbp/3p2p1/4P2n/3P4/2N5/PPP1BPPP/R...
#
#                                 url last_move
#  0   https://lichess.org/fMBJvETi#1      e2e4
#  1   https://lichess.org/fMBJvETi#2      g7g6
#  2   https://lichess.org/fMBJvETi#3      b1c3
#  3   https://lichess.org/fMBJvETi#4      f8g7
#  4   https://lichess.org/fMBJvETi#5      d2d4
#  5   https://lichess.org/fMBJvETi#6      g8f6
#  6   https://lichess.org/fMBJvETi#7      e4e5
#  7   https://lichess.org/fMBJvETi#8      f6h5
#  8   https://lichess.org/fMBJvETi#9      f1e2
#  9  https://lichess.org/fMBJvETi#10      d7d6  ,
#      taken  invalid  evaluation  evaluation_change  accuracy  taken_score  \
#  0      []    False          22               -286         0            0
#  1      []    False          30                  8       100            0
#  2      []    False          33                  3       100            0
#  3      []    False          33                  0       100            0
#  4      []    False          30                 -3       100            0
#  5      []    False          31                  1       100            0
#  6     [n]    False           5                -26        75          300
#  7  [n, B]    False           7                  2       100            0
#  8  [n, B]    False         -14                -21       100            0
#  9  [n, B]    False          48                 62        50            0
#
#                                                   fen  \
#  0  rnbqkbnr/pppppppp/8/8/4P3/8/PPPP1PPP/RNBQKBNR ...
#  1  rnbqkbnr/pppp1ppp/8/4p3/4P3/8/PPPP1PPP/RNBQKBN...
#  2  rnbqkbnr/pppp1ppp/8/4p3/4P3/5N2/PPPP1PPP/RNBQK...
#  3  r1bqkbnr/pppp1ppp/2n5/4p3/4P3/5N2/PPPP1PPP/RNB...
#  4  r1bqkbnr/pppp1ppp/2n5/1B2p3/4P3/5N2/PPPP1PPP/R...
#  5  r1bqkbnr/1ppp1ppp/p1n5/1B2p3/4P3/5N2/PPPP1PPP/...
#  6  r1bqkbnr/1ppp1ppp/p1B5/4p3/4P3/5N2/PPPP1PPP/RN...
#  7  r1bqkbnr/1pp2ppp/p1p5/4p3/4P3/5N2/PPPP1PPP/RNB...
#  8  r1bqkbnr/1pp2ppp/p1p5/4p3/4P3/2N2N2/PPPP1PPP/R...
#  9  r1bqk1nr/1pp2ppp/p1pb4/4p3/4P3/2N2N2/PPPP1PPP/...
#
#                                 url last_move
#  0   https://lichess.org/7vfFivMh#1      e2e4
#  1   https://lichess.org/7vfFivMh#2      e7e5
#  2   https://lichess.org/7vfFivMh#3      g1f3
#  3   https://lichess.org/7vfFivMh#4      b8c6
#  4   https://lichess.org/7vfFivMh#5      f1b5
#  5   https://lichess.org/7vfFivMh#6      a7a6
#  6   https://lichess.org/7vfFivMh#7      b5c6
#  7   https://lichess.org/7vfFivMh#8      d7c6
#  8   https://lichess.org/7vfFivMh#9      b1c3
#  9  https://lichess.org/7vfFivMh#10      f8d6  ]

# %%
eco_dict = eco.set_index('ECO Code')['Name'].to_dict()

games['sub_opening_name'] = games['ECO'].map(eco_dict)

# %%
#Visualizazion of given game
game=games.iloc[900]

move_number=3
row={}
row['taken']=[]
board=chess.Board()
for san in game['moves'][:move_number]:
    parsed_san=board.parse_san(san)#move by the san "Standard Algebraic Notation"
    taken=board.piece_at(parsed_san.to_square)
    if taken:
        row['taken'].append(taken.__str__())
    move=board.push_san(san)
board
# Out:
# Board('rnbqkbnr/ppppp1pp/8/5p2/2PP4/8/PP2PPPP/RNBQKBNR b KQkq - 0 2')

# %%
game_index = 1
df = pd.DataFrame(games_analysis[game_index]['evaluation_change'], columns=['evaluation_change'])
df2 = pd.DataFrame(games_analysis[game_index]['evaluation'], columns=['evaluation'])


# Assuming games_analysis[0]['evaluation_change'] is a list or similar structure
df['move_number'] = range(1, len(df) + 1)
df2['move_number'] = range(1, len(df) + 1)

plt.figure(figsize=(10, 6))
plt.bar(df['move_number'], df['evaluation_change'], color=df['evaluation_change'].apply(lambda x: 'blue' if x >= 0 else 'red'))
plt.xlabel('Move Number')
plt.ylabel('Evaluation Change')
plt.title('Evaluation Change per Move')
plt.show()

plt.figure(figsize=(10, 6))
plt.bar(df2['move_number'], df2['evaluation'], color=df2['evaluation'].apply(lambda x: 'blue' if x >= 0 else 'red'))
plt.xlabel('Move Number')
plt.ylabel('Evaluation')
plt.title('Evaluation')
plt.show()

biggest_change = 0
move = 1

for index, change in enumerate(df['evaluation_change'], start=1):
    # Check if the absolute value of the change is larger than the biggest_change
    if abs(change) > abs(biggest_change):
        biggest_change = change
        move = index

print(f"The largest change was {biggest_change} on move {move}.")
print(games_analysis[game_index]['url'][move])
# Out:
# The largest change was -236 on move 3.
# https://lichess.org/W4qIfyPj#4

# %%
games_white = games[0:80][games['player_color'] == "White"]
agg_color_opening = games_white.groupby(['player_color', 'opening_name']).size().reset_index(name='count')
agg_color_opening_score = games_white.groupby(['opening_name', 'score']).size().reset_index(name='count')


games_black = games[0:80][games['player_color'] == "Black"]
agg_color_opening = games_black.groupby(['player_color', 'opening_name']).size().reset_index(name='count')
agg_color_opening_score = games_black.groupby(['opening_name', 'score']).size().reset_index(name='count')



# Include the count of games per opening as well
# Out:
# C:\Users\aober\AppData\Local\Temp\ipykernel_41240\344842361.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   games_white = games[0:80][games['player_color'] == "White"]
# C:\Users\aober\AppData\Local\Temp\ipykernel_41240\344842361.py:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   games_black = games[0:80][games['player_color'] == "Black"]

# %%
games_black
# Out:
#                                               headers  \
# 0   {'_tag_roster': {'Event': 'Rated Bullet game',...
# 1   {'_tag_roster': {'Event': 'Rated Bullet game',...
# 3   {'_tag_roster': {'Event': 'Rated Bullet game',...
# 6   {'_tag_roster': {'Event': 'Rated Bullet game',...
# 9   {'_tag_roster': {'Event': 'Rated Bullet game',...
# 10  {'_tag_roster': {'Event': 'Rated Bullet game',...
# 12  {'_tag_roster': {'Event': 'Rated Bullet game',...
# 14  {'_tag_roster': {'Event': 'Rated Bullet game',...
# 17  {'_tag_roster': {'Event': 'Rated Bullet game',...
# 18  {'_tag_roster': {'Event': 'Rated Bullet game',...
# 22  {'_tag_roster': {'Event': 'Rated Bullet game',...
# 24  {'_tag_roster': {'Event': 'Rated Bullet game',...
# 25  {'_tag_roster': {'Event': 'Rated Bullet game',...
# 26  {'_tag_roster': {'Event': 'Rated Bullet game',...
# 29  {'_tag_roster': {'Event': 'Rated Bullet game',...
# 31  {'_tag_roster': {'Event': 'Rated Bullet game',...
# 33  {'_tag_roster': {'Event': 'Rated Bullet game',...
# 35  {'_tag_roster': {'Event': 'Rated Bullet game',...
# 36  {'_tag_roster': {'Event': 'Rated Bullet game',...
# 40  {'_tag_roster': {'Event': 'Rated Bullet game',...
# 41  {'_tag_roster': {'Event': 'Rated Bullet game',...
# 43  {'_tag_roster': {'Event': 'Rated Bullet game',...
# 44  {'_tag_roster': {'Event': 'Rated Bullet game',...
# 47  {'_tag_roster': {'Event': 'Rated Bullet game',...
# 48  {'_tag_roster': {'Event': 'Rated Bullet game',...
# 50  {'_tag_roster': {'Event': 'Rated Bullet game',...
# 51  {'_tag_roster': {'Event': 'Rated Bullet game',...
# 54  {'_tag_roster': {'Event': 'Rated Bullet game',...
# 57  {'_tag_roster': {'Event': 'Rated Bullet game',...
# 59  {'_tag_roster': {'Event': 'Rated Bullet game',...
# 60  {'_tag_roster': {'Event': 'Rated Blitz game', ...
# 62  {'_tag_roster': {'Event': 'Rated Blitz game', ...
# 64  {'_tag_roster': {'Event': 'Rated Blitz game', ...
# 65  {'_tag_roster': {'Event': 'Rated Blitz game', ...
# 69  {'_tag_roster': {'Event': 'Rated Blitz game', ...
# 70  {'_tag_roster': {'Event': 'Rated Bullet game',...
# 71  {'_tag_roster': {'Event': 'Rated Bullet game',...
# 75  {'_tag_roster': {'Event': 'Rated Blitz game', ...
# 76  {'_tag_roster': {'Event': 'Rated Blitz game', ...
# 78  {'_tag_roster': {'Event': 'Rated Bullet game',...
# 81  {'_tag_roster': {'Event': 'Rated Bullet game',...
# 82  {'_tag_roster': {'Event': 'Rated Blitz game', ...
# 84  {'_tag_roster': {'Event': 'Rated Bullet game',...
# 86  {'_tag_roster': {'Event': 'Rated Bullet game',...
# 89  {'_tag_roster': {'Event': 'Rated Bullet game',...
# 91  {'_tag_roster': {'Event': 'Rated Blitz game', ...
# 92  {'_tag_roster': {'Event': 'Rated Bullet game',...
# 94  {'_tag_roster': {'Event': 'Rated Bullet game',...
# 96  {'_tag_roster': {'Event': 'Rated Bullet game',...
# 99  {'_tag_roster': {'Event': 'Rated Bullet game',...
#
#                                                 moves  \
# 0   [e2e4, e7e5, g1f3, b8c6, f1b5, a7a6, b5c6, d7c...
# 1   [c2c4, e7e5, c4c5, f8c5, g2g3, g8f6, f1g2, d7d...
# 3   [e2e4, e7e5, g1f3, b8c6, f1c4, f8c5, b2b4, c5b...
# 6   [d2d4, f7f5, c1f4, g8f6, g1f3, e7e6, e2e3, b7b...
# 9   [e2e4, e7e5, g1f3, b8c6, f1c4, f8c5, c2c3, g8f...
# 10  [d2d4, f7f5, c1f4, g8f6, e2e3, e7e6, g1f3, f8e...
# 12  [e2e4, e7e5, f1c4, b8c6, d2d3, f8c5, c2c3, g8f...
# 14  [d2d4, f7f5, c2c4, g8f6, b1c3, e7e6, e2e3, f8b...
# 17  [d2d3, e7e5, e2e4, b8c6, g1f3, f8c5, f1e2, g8f...
# 18  [e2e4, e7e5, f2f4, e5f4, d2d4, g7g5, g1f3, f8e...
# 22  [e2e4, e7e5, d2d3, b8c6, b1c3, f8c5, a2a3, g8f...
# 24  [e2e4, e7e5, f2f4, e5f4, g1f3, g7g5, f1c4, b8c...
# 25  [e2e4, e7e5, g1f3, b8c6, f1b5, a7a6, b5a4, g8f...
# 26  [e2e4, e7e5, f1c4, b8c6, g1f3, f8c5, f3e5, c6e...
# 29  [e2e4, e7e5, g1f3, b8c6, f1b5, a7a6, b5c6, d7c...
# 31  [c2c4, e7e5, b1c3, b8c6, g2g3, f8b4, a2a3, b4c...
# 33  [d2d4, f7f5, c1f4, g8f6, e2e3, e7e6, f1d3, b7b...
# 35  [e2e4, e7e5, a2a3, b8c6, b1c3, f8c5, h2h3, g8f...
# 36  [e2e4, e7e5, g1f3, b8c6, d2d4, c6d4, f3d4, e5d...
# 40  [d2d3, e7e5, e2e3, b8c6, c2c3, f8c5, f2f3, g8f...
# 41  [e2e4, e7e5, g1f3, b8c6, b1c3, f8b4, d2d4, b4c...
# 43  [d2d4, f7f5, c2c4, g8f6, b1c3, e7e6, g1f3, f8b...
# 44  [d2d4, f7f5, c2c4, g8f6, e2e3, e7e6, g1f3, f8b...
# 47  [e2e4, e7e5, g1f3, b8c6, f1c4, f8c5, e1g1, g8f...
# 48  [b2b3, e7e5, c1b2, b8c6, b1c3, f8b4, e2e3, g8f...
# 50  [d2d4, f7f5, c2c4, g8f6, b1c3, e7e6, c1g5, h7h...
# 51  [d2d4, f7f5, c2c4, g8f6, b1c3, e7e6, g1f3, f8b...
# 54  [e2e3, e7e5, b2b3, d7d5, c1b2, b8c6, b1c3, g8f...
# 57  [e2e4, e7e5, f1c4, b8c6, g1f3, f8c5, c4f7, e8f...
# 59  [e2e4, e7e5, f1c4, b8c6, g1f3, f8c5, f3g5, d8g...
# 60  [e2e4, e7e5, d2d4, e5d4, c2c3, d4c3, f1c4, b8c...
# 62  [e2e4, e7e5, g1f3, b8c6, f1b5, a7a6, b5c6, d7c...
# 64  [e2e4, e7e5, g1f3, b8c6, f1c4, f8c5, c2c3, g8f...
# 65  [d2d4, f7f5, g1f3, g8f6, c2c4, e7e6, d4d5, f8e...
# 69  [e2e4, e7e5, b1c3, b8c6, f1c4, f8c5, d1g4, d8f...
# 70  [e2e4, e7e5, g1f3, b8c6, f1c4, f8c5, d2d3, d7d...
# 71  [g1f3, b8c6, d2d4, d7d5, g2g3, c8f5, f1g2, e7e...
# 75  [d2d4, f7f5, g1f3, g8f6, c2c3, e7e6, c1g5, h7h...
# 76  [d2d4, f7f5, c2c4, g8f6, b1c3, e7e6, g1f3, f8b...
# 78  [d2d3, e7e5, e2e3, b8c6, a2a3, f8c5, h2h3, d7d...
# 81  [e2e4, e7e5, g1f3, b8c6, d2d4, e5d4, f3d4, c6d...
# 82  [e2e4, e7e5, g1e2, b8c6, e2g3, g8f6, a2a3, f8c...
# 84  [e2e4, e7e5, b1c3, b8c6, f1b5, a7a6, b5c6, d7c...
# 86  [e2e4, e7e5, d2d4, e5d4, g1f3, b8c6, c2c3, d4c...
# 89  [d2d4, d7d5, c1f4, c8f5, g1f3, e7e6, e2e3, f8d...
# 91  [e2e4, e7e5, g1f3, b8c6, f1c4, f8c5, c2c3, g8f...
# 92  [e2e4, e7e5, f2f4, b8c6, g1f3, e5f4, f1c4, d7d...
# 94  [e2e4, e7e5, d2d4, e5d4, d1d4, d8f6, d4e3, f6b...
# 96  [e2e4, e7e5, d2d4, e5d4, d1d4, d8f6, d4e3, f6b...
# 99  [e2e4, e7e5, g1f3, b8c6, f1b5, a7a6, b5a4, g8f...
#
#                       lichess_id  white_elo  black_elo  ECO  \
# 0   https://lichess.org/R5xvWQmB       1393       1490  C68
# 1   https://lichess.org/W4qIfyPj       1468       1485  A20
# 3   https://lichess.org/vBCaaIq2       1549       1484  C52
# 6   https://lichess.org/zGzfZ9ew       1474       1464  A80
# 9   https://lichess.org/KEkOpdsl       1492       1483  C54
# 10  https://lichess.org/nItMHMv2       1493       1489  A80
# 12  https://lichess.org/t6kU1MF8       1469       1488  C23
# 14  https://lichess.org/BcoQdj3B       1397       1478  A85
# 17  https://lichess.org/KuRI2yIi       1473       1473  C20
# 18  https://lichess.org/eT7BiAGe       1449       1467  C37
# 22  https://lichess.org/yQhxpKiF       1454       1465  C20
# 24  https://lichess.org/4u0ZZXT8       1465       1467  C37
# 25  https://lichess.org/Z6GsD7DN       1456       1460  C77
# 26  https://lichess.org/pPDQft7I       1537       1451  C50
# 29  https://lichess.org/7vfFivMh       1442       1460  C68
# 31  https://lichess.org/XGEugRGY       1463       1460  A25
# 33  https://lichess.org/ZDnN7wII       1475       1477  A80
# 35  https://lichess.org/G2z36dgj       1487       1485  C20
# 36  https://lichess.org/m1fefSDw       1459       1496  C44
# 40  https://lichess.org/GDj9qhYo       1477       1486  A00
# 41  https://lichess.org/MG9RdYcQ       1510       1496  C46
# 43  https://lichess.org/vYsnL1Zz       1478       1494  A85
# 44  https://lichess.org/ojjYWDoh       1496       1506  A84
# 47  https://lichess.org/MyXcm5fi       1520       1515  C50
# 48  https://lichess.org/bq73ly7c       1525       1501  A01
# 50  https://lichess.org/Zf9fxPTg       1411       1503  A85
# 51  https://lichess.org/U6ARlmxc       1551       1515  A85
# 54  https://lichess.org/fHpwwnUy       1553       1529  A00
# 57  https://lichess.org/UGndj1OU       1559       1545  C50
# 59  https://lichess.org/ccF9ymdW       1570       1542  C50
# 60  https://lichess.org/CCaKdcOp       1764       1761  C44
# 62  https://lichess.org/ldwYkPgo       1761       1761  C69
# 64  https://lichess.org/xXCG4qdX       1780       1759  C54
# 65  https://lichess.org/dg4jcdk1       1710       1749  A80
# 69  https://lichess.org/gG6mbJbz       1752       1782  C25
# 70  https://lichess.org/PXzqwFBs       1489       1559  C50
# 71  https://lichess.org/yPWn6Sa4       1587       1574  D02
# 75  https://lichess.org/4dbfMnAP       1706       1753  A80
# 76  https://lichess.org/bP8fZIoV       1721       1755  A85
# 78  https://lichess.org/73nodC2K       1620       1587  A00
# 81  https://lichess.org/OSR0WOel       1601       1571  C44
# 82  https://lichess.org/FCSHIRrq       1804       1819  C20
# 84  https://lichess.org/QgBUN5os       1590       1585  C25
# 86  https://lichess.org/UFbGyU5p       1561       1584  C44
# 89  https://lichess.org/HJEvMFwi       1640       1590  D00
# 91  https://lichess.org/NIw0ifti       1804       1823  C56
# 92  https://lichess.org/5IF61Cnc       1590       1590  C34
# 94  https://lichess.org/7UXYWv5L       1564       1591  C21
# 96  https://lichess.org/A1NuzHhH       1563       1592  C21
# 99  https://lichess.org/Pd6Y2RVY       1555       1598  C70
#
#                                          opening_name              event  \
# 0      Ruy Lopez: Exchange Variation, Keres Variation  Rated Bullet game
# 1           English Opening: King's English Variation  Rated Bullet game
# 3          Italian Game: Evans Gambit, Pierce Defense  Rated Bullet game
# 6                                       Dutch Defense  Rated Bullet game
# 9          Italian Game: Giuoco Piano, Greco's Attack  Rated Bullet game
# 10                                      Dutch Defense  Rated Bullet game
# 12                                   Bishop's Opening  Rated Bullet game
# 14            Dutch Defense: Queen's Knight Variation  Rated Bullet game
# 17              King's Pawn Game: Leonardis Variation  Rated Bullet game
# 18         King's Gambit Accepted: Rosentreter Gambit  Rated Bullet game
# 22              King's Pawn Game: Leonardis Variation  Rated Bullet game
# 24             King's Gambit Accepted: Blachly Gambit  Rated Bullet game
# 25     Ruy Lopez: Morphy Defense, Anderssen Variation  Rated Bullet game
# 26                         Italian Game: Giuoco Piano  Rated Bullet game
# 29     Ruy Lopez: Exchange Variation, Keres Variation  Rated Bullet game
# 31  English Opening: King's English Variation, Rev...  Rated Bullet game
# 33                                      Dutch Defense  Rated Bullet game
# 35              King's Pawn Game: Mengarini's Opening  Rated Bullet game
# 36                       Scotch Game: Lolli Variation  Rated Bullet game
# 40                       Mieses Opening: Reversed Rat  Rated Bullet game
# 41                              Three Knights Opening  Rated Bullet game
# 43            Dutch Defense: Queen's Knight Variation  Rated Bullet game
# 44                    Dutch Defense: Normal Variation  Rated Bullet game
# 47                         Italian Game: Deutz Gambit  Rated Bullet game
# 48              Nimzo-Larsen Attack: Modern Variation  Rated Bullet game
# 50            Dutch Defense: Queen's Knight Variation  Rated Bullet game
# 51            Dutch Defense: Queen's Knight Variation  Rated Bullet game
# 54                               Van't Kruijs Opening  Rated Bullet game
# 57                        Italian Game: Jerome Gambit  Rated Bullet game
# 59                         Italian Game: Giuoco Piano  Rated Bullet game
# 60  Scotch Game: G̦ring Gambit, Double Pawn Sacri...   Rated Blitz game
# 62  Ruy Lopez: Exchange Variation, King's Bishop V...   Rated Blitz game
# 64    Italian Game: Classical Variation, Greco Gambit   Rated Blitz game
# 65                                      Dutch Defense   Rated Blitz game
# 69  Vienna Game: Stanley Variation, Meitner-Mieses...   Rated Blitz game
# 70                    Italian Game: Giuoco Pianissimo  Rated Bullet game
# 71              Queen's Pawn Game: Chigorin Variation  Rated Bullet game
# 75                                      Dutch Defense   Rated Blitz game
# 76            Dutch Defense: Queen's Knight Variation   Rated Blitz game
# 78                       Mieses Opening: Reversed Rat  Rated Bullet game
# 81                       Scotch Game: Lolli Variation  Rated Bullet game
# 82                   King's Pawn Game: Alapin Opening   Rated Blitz game
# 84                     Vienna Game: Max Lange Defense  Rated Bullet game
# 86  Scotch Game: G̦ring Gambit, Double Pawn Sacri...  Rated Bullet game
# 89       Queen's Pawn Game: Accelerated London System  Rated Bullet game
# 91  Italian Game: Scotch Gambit, Walbrodt-Baird Ga...   Rated Blitz game
# 92            King's Gambit Accepted: MacLeod Defense  Rated Bullet game
# 94                                        Center Game  Rated Bullet game
# 96                                        Center Game  Rated Bullet game
# 99                          Ruy Lopez: Morphy Defense  Rated Bullet game
#
#    player_color  score                         sub_opening_name  \
# 0         Black    0.0                      Ruy Lopez, Exchange
# 1         Black    1.0                                  English
# 3         Black    1.0                             Evans Gambit
# 6         Black    1.0                                    Dutch
# 9         Black    0.0                             Giuoco Piano
# 10        Black    0.0                                    Dutch
# 12        Black    0.0                         Bishop's Opening
# 14        Black    1.0                     Dutch, with c4 & Nc3
# 17        Black    0.0                         King's Pawn Game
# 18        Black    1.0                   King's Gambit Accepted
# 22        Black    0.0                         King's Pawn Game
# 24        Black    0.0                   King's Gambit Accepted
# 25        Black    1.0                                Ruy Lopez
# 26        Black    1.0                             Giuoco Piano
# 29        Black    1.0                      Ruy Lopez, Exchange
# 31        Black    0.0                                  English
# 33        Black    0.0                                    Dutch
# 35        Black    0.5                         King's Pawn Game
# 36        Black    0.0                         King's Pawn Game
# 40        Black    1.0                         Uncommon Opening
# 41        Black    0.0                            Three Knights
# 43        Black    0.0                     Dutch, with c4 & Nc3
# 44        Black    0.0                                    Dutch
# 47        Black    0.0                             Giuoco Piano
# 48        Black    1.0                  Nimzovich-Larsen Attack
# 50        Black    0.0                     Dutch, with c4 & Nc3
# 51        Black    0.0                     Dutch, with c4 & Nc3
# 54        Black    0.0                         Uncommon Opening
# 57        Black    0.0                             Giuoco Piano
# 59        Black    1.0                             Giuoco Piano
# 60        Black    1.0                         King's Pawn Game
# 62        Black    0.0  Ruy Lopez, Exchange, Gligoric Variation
# 64        Black    0.0                             Giuoco Piano
# 65        Black    1.0                                    Dutch
# 69        Black    0.0                                   Vienna
# 70        Black    0.0                             Giuoco Piano
# 71        Black    0.0                        Queen's Pawn Game
# 75        Black    1.0                                    Dutch
# 76        Black    0.5                     Dutch, with c4 & Nc3
# 78        Black    0.0                         Uncommon Opening
# 81        Black    1.0                         King's Pawn Game
# 82        Black    0.0                         King's Pawn Game
# 84        Black    0.0                                   Vienna
# 86        Black    1.0                         King's Pawn Game
# 89        Black    0.0                        Queen's Pawn Game
# 91        Black    1.0                              Two Knights
# 92        Black    0.0                   King's Gambit Accepted
# 94        Black    1.0                              Center Game
# 96        Black    0.0                              Center Game
# 99        Black    0.0                                Ruy Lopez
#
#     average_accuracy
# 0               92.5
# 1               75.0
# 3               90.0
# 6               87.5
# 9               95.0
# 10              92.5
# 12              97.5
# 14              77.5
# 17              87.5
# 18              45.0
# 22              82.5
# 24              67.5
# 25              80.0
# 26              67.5
# 29              85.0
# 31              87.5
# 33              95.0
# 35              87.5
# 36              90.0
# 40              52.5
# 41              80.0
# 43              87.5
# 44              97.5
# 47              82.5
# 48              50.0
# 50              75.0
# 51              82.5
# 54              82.5
# 57              67.5
# 59              72.5
# 60              57.5
# 62              90.0
# 64              97.5
# 65              85.0
# 69              72.5
# 70              92.5
# 71              97.5
# 75              85.0
# 76              82.5
# 78              67.5
# 81              92.5
# 82              67.5
# 84              90.0
# 86              80.0
# 89              90.0
# 91              97.5
# 92              45.0
# 94              67.5
# 96              67.5
# 99              70.0

# %%
#Plot accuracy per opening

#WHITE
index_white = games_white.index.tolist()
games_analysis10 = [games_analysis[i] for i in index_white]
games_white['average_accuracy'] = [np.mean(games_analysis10[i]["accuracy"]) for i in range(len(games_analysis10))]
# Now group by opening_name and calculate the mean of average_accuracy
agg_accuracy_opening = games_white.groupby('opening_name')['average_accuracy'].mean().reset_index(name='mean_accuracy')
agg_accuracy_opening['count'] = games_white.groupby('opening_name').size().reset_index(name='count')['count']

w_agg_accuracy_main_opening = games_white.groupby('sub_opening_name')['average_accuracy'].mean().reset_index(name='mean_accuracy')
w_agg_accuracy_main_opening['count'] = games_white.groupby('sub_opening_name').size().reset_index(name='count')['count']

#BLACK
index_black = games_black.index.tolist()
games_analysis_black = [games_analysis[i] for i in index_black]
games_black['average_accuracy'] = [np.mean(games_analysis_black[i]["accuracy"]) for i in range(len(games_analysis_black))]
# Now group by opening_name and calculate the mean of average_accuracy
agg_accuracy_opening_black = games_black.groupby('opening_name')['average_accuracy'].mean().reset_index(name='mean_accuracy')
agg_accuracy_opening_black['count'] = games_black.groupby('opening_name').size().reset_index(name='count')['count']

b_agg_accuracy_main_opening = games_black.groupby('sub_opening_name')['average_accuracy'].mean().reset_index(name='mean_accuracy')
b_agg_accuracy_main_opening['count'] = games_black.groupby('sub_opening_name').size().reset_index(name='count')['count']
b_agg_accuracy_main_opening = b_agg_accuracy_main_opening.sort_values('count', ascending=False)

# %%
# Ensure the DataFrames are sorted by 'mean_accuracy'
agg_accuracy_opening = agg_accuracy_opening.sort_values('mean_accuracy', ascending=False)
agg_accuracy_opening_black = agg_accuracy_opening_black.sort_values('mean_accuracy', ascending=False)

w_agg_accuracy_main_opening = w_agg_accuracy_main_opening.sort_values('mean_accuracy', ascending=False)
b_agg_accuracy_main_opening = b_agg_accuracy_main_opening.sort_values('mean_accuracy', ascending=False)


fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20, 6))

# Plot for playing white, using 'sub_opening_name'
sns.barplot(x='mean_accuracy', y='sub_opening_name', data=w_agg_accuracy_main_opening, palette='Greys', ax=ax1)
ax1.set_title('Mean Accuracy by Sub-Opening, playing white')
ax1.set_xlabel('Mean Accuracy')
ax1.set_ylabel('Sub-Opening Name')

# Plot for playing black, using 'sub_opening_name'
sns.barplot(x='mean_accuracy', y='sub_opening_name', data=b_agg_accuracy_main_opening, palette='Greys', ax=ax2)
ax2.set_title('Mean Accuracy by Sub-Opening, playing black')
ax2.set_xlabel('Mean Accuracy')
ax2.set_ylabel('Sub-Opening Name')

plt.tight_layout()
plt.show()
#PLOTS WHITE

agg_accuracy_opening = agg_accuracy_opening.sort_values('mean_accuracy', ascending=False)
agg_accuracy_opening_black = agg_accuracy_opening_black.sort_values('mean_accuracy', ascending=False)
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20, 6))

sns.barplot(x='mean_accuracy', y='opening_name', data=agg_accuracy_opening, palette='Greys', ax=ax1)
ax1.set_title('Mean Accuracy by Opening, playing white')
ax1.set_xlabel('Mean Accuracy')
ax1.set_ylabel('Opening Name')

black_palette = sns.light_palette("black", reverse=True, as_cmap=False)
sns.barplot(x='mean_accuracy', y='opening_name', data=agg_accuracy_opening_black, palette='Greys', ax=ax2)
ax2.set_title('Mean Accuracy by Opening, playing black')
ax2.set_xlabel('Mean Accuracy')
ax2.set_ylabel('Opening Name')

plt.tight_layout()
plt.show()


agg_accuracy_opening = agg_accuracy_opening.sort_values('count', ascending=False)
agg_accuracy_opening_black = agg_accuracy_opening_black.sort_values('count', ascending=False)
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20, 6))

# Plot for white
sns.barplot(x='count', y='opening_name', data=agg_accuracy_opening, palette='Greys', ax=ax1)
ax1.set_title('Count of Games by Opening (White)')
ax1.set_xlabel('Count of Games')
ax1.set_ylabel('Opening Name')

# Plot for black
sns.barplot(x='count', y='opening_name', data=agg_accuracy_opening_black, palette='Greys', ax=ax2)
ax2.set_title('Count of Games by Opening (Black)')
ax2.set_xlabel('Count of Games')
ax2.set_ylabel('Opening Name')

plt.tight_layout()
plt.show()


# Scatterplot Amount of games and accuracy for grouped openings
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20, 6))

# Scatter plot for playing white, with colors representing different sub-openings
sns.scatterplot(x='count', y='mean_accuracy', hue='grouped_opening_name', data=w_agg_accuracy_main_opening, ax=ax1, palette='tab10', s=100)  # Adjust s for size
ax1.set_title('Accuracy vs. Count of Games by Main-Opening (White)')
ax1.set_xlabel('Count of Games')
ax1.set_ylabel('Mean Accuracy')
ax1.legend(title='Sub-Opening Name')

# Scatter plot for playing black, with colors representing different sub-openings
sns.scatterplot(x='count', y='mean_accuracy', hue='grouped_opening_name', data=b_agg_accuracy_main_opening, ax=ax2, palette='tab10', s=100)  # Adjust s for size
ax2.set_title('Accuracy vs. Count of Games by Main-Opening (Black)')
ax2.set_xlabel('Count of Games')
ax2.set_ylabel('Mean Accuracy')
ax2.legend(title='Sub-Opening Name')

plt.tight_layout()
plt.show()
