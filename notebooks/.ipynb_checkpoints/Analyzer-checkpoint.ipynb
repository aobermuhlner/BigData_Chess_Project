# %%
# Analyze games and save evaluation for each move

# %%
import chess #https://github.com/niklasf/python-chess
from stockfish import Stockfish

#We'll create an intentionally worse stockfish engine to estimate complexity of positions
stockfish_good=Stockfish("C:/Users/aober/Documents/Data_Science_Studium/4Semester/BigData/stockfish/stockfish-windows-x86-64-avx2.exe")
stockfish_good.set_depth(20)#How deep the AI looks
stockfish_good.set_skill_level(20)#Highest rank stockfish
import chess.pgn
import pandas as pd
pd.options.display.max_columns=999
import datetime
import tqdm
import zipfile

# %%
games=pd.read_csv("../../testData/loaded_games.csv")
games
# Out:
#                                                 headers  \
# 0     {'_tag_roster': {'Event': 'Rated Blitz game', ...
# 1     {'_tag_roster': {'Event': 'Rated Rapid game', ...
# 2     {'_tag_roster': {'Event': 'Rated Blitz game', ...
# 3     {'_tag_roster': {'Event': 'Rated Blitz game', ...
# 4     {'_tag_roster': {'Event': 'Rated Blitz tournam...
# ...                                                 ...
# 1995  {'_tag_roster': {'Event': 'Rated Blitz game', ...
# 1996  {'_tag_roster': {'Event': 'Rated Blitz tournam...
# 1997  {'_tag_roster': {'Event': 'Rated Blitz game', ...
# 1998  {'_tag_roster': {'Event': 'Rated Blitz game', ...
# 1999  {'_tag_roster': {'Event': 'Rated Blitz game', ...
#
#                                                   moves lichess_id  ECO  \
# 0     ['e2e4', 'e7e6', 'd2d4', 'd7d5', 'b1c3', 'f8b4...   kuUOsOML  C18
# 1     ['e2e4', 'c7c5', 'g1f3', 'd7d6', 'b1c3', 'g8f6...   YcFqJqyM  B50
# 2     ['e2e4', 'g7g6', 'd2d4', 'f8g7', 'b1c3', 'c7c6...   AY9kSWFt  B06
# 3     ['d2d4', 'd7d5', 'c2c4', 'c7c6', 'b1c3', 'g8f6...   ZZiTCh8x  D52
# 4     ['d2d4', 'f7f5', 'g2g3', 'g8f6', 'f1g2', 'g7g6...   DHvjCHM2  A81
# ...                                                 ...        ...  ...
# 1995  ['e2e4', 'd7d6', 'd2d4', 'g8f6', 'b1c3', 'g7g6...   qmP74cCM  B08
# 1996  ['e2e4', 'e7e6', 'b2b3', 'd7d5', 'c1b2', 'd5e4...   tDWQPO0F  C00
# 1997  ['e2e4', 'c7c5', 'g1f3', 'd7d6', 'd2d4', 'c5d4...   wbiRGx4h  B53
# 1998  ['e2e4', 'e7e5', 'g1f3', 'b8c6', 'f1b5', 'g8f6...   KR6JypMY  C67
# 1999  ['e2e4', 'c7c5', 'g1f3', 'd7d6', 'd2d4', 'c5d4...   wro58jZS  B90
#
#       white_elo  black_elo                                       opening_name  \
# 0          2413       2254  French Defense: Winawer Variation, Poisoned Pa...
# 1          2323       2415                                   Sicilian Defense
# 2          2497       2426                      Modern Defense: Standard Line
# 3          2387       2416                            Queen's Gambit Declined
# 4          2288       2469            Dutch Defense: Semi-Leningrad Variation
# ...         ...        ...                                                ...
# 1995       2412       2424                  Pirc Defense: Classical Variation
# 1996       2429       2251  French Defense: Horwitz Attack, Papa-Ticulat G...
# 1997       2401       2464              Sicilian Defense: Chekhover Variation
# 1998       2383       2462      Ruy Lopez: Berlin Defense, l'Hermet Variation
# 1999       2430       2365        Sicilian Defense: Najdorf, Lipnitsky Attack
#
#       white_score
# 0             0.5
# 1             1.0
# 2             0.5
# 3             0.0
# 4             1.0
# ...           ...
# 1995          0.0
# 1996          1.0
# 1997          1.0
# 1998          0.0
# 1999          1.0
#
# [2000 rows x 8 columns]

# %%
move_number=15
row={}
row['taken']=[]
board=chess.Board()
print(game['moves'])
for san in game['moves'][:move_number]:
    parsed_san=board.parse_san(san) #move by the san "Standard Algebraic Notation"
    taken=board.piece_at(parsed_san.to_square)
    if taken:
        row['taken'].append(taken.__str__())
    move=board.push_san(san)
# Out:
# ['e2e4', 'e7e6', 'd2d4', 'd7d5', 'b1c3', 'f8b4', 'e4e5', 'g8e7', 'a2a3', 'b4c3', 'b2c3', 'c7c5', 'd1g4', 'd8c7', 'g4g7', 'h8g8', 'g7h7', 'c5d4', 'g1e2', 'd4c3', 'f2f4', 'd5d4', 'h2h4', 'b8c6', 'h4h5', 'c8d7', 'h5h6', 'e8c8', 'h7d3', 'g8g6', 'h6h7', 'd8h8', 'e2d4', 'c6d4', 'd3d4', 'c8b8', 'h1h3', 'e7f5', 'd4b4', 'd7c6', 'a3a4', 'c6g2', 'h3c3', 'c7b6', 'b4b6', 'a7b6', 'c1a3', 'g2f1', 'e1c1', 'f1g2', 'a3d6', 'b8a7', 'c3c7', 'h8h7', 'c7c8', 'h7g7', 'd6b8', 'a7a6', 'b8c7', 'g7g8', 'd1d8', 'g8d8', 'c8d8', 'a6a7', 'c7b8', 'a7a6', 'b8c7', 'a6a7', 'c7b8', 'a7a8', 'b8c7', 'a8a7']

# %% [markdown]
# # Running Stored Game

# %%
#Standard point values for different pieces. Lowercase is white piece and uppercase is black
piece_scores={
    "p": 1,
    "P": -1,
    "r": 5,
    "R": -5,
    "n": 3,
    "N": -3,
    "b": 3,
    "B": -3,
    "q": 9,
    "Q": -9
}

# %% [markdown]
# All we have to do is iterate through moves. For [chessnit.com](http://www.chessnit.com) I was looking at specific positions so I simply chose a random number to evaluate in each game.

# %%
import random

#Used by chessnit.com
def build_stored_game_analysis(game, move_number, prev_evaluation):
    row={}
    row['move_number']=move_number
    row['taken']=[]
    board=chess.Board()
    for san in game['moves'][:move_number]:
        parsed_san=board.parse_san(san)
        taken=board.piece_at(parsed_san.to_square)
        if taken:
            row['taken'].append(taken.__str__())
        move=board.push_san(san)
    row['invalid']=bool(board.promoted) or bool(board.outcome())
    stockfish_good.set_fen_position(board.fen())
    evaluation=stockfish_good.get_evaluation()
    row['evaluation']=evaluation['value']
    row['evaluation_change']=evaluation['value']-prev_evaluation
    
    
    row['taken_score']=sum([piece_scores.get(p) for p in row['taken']])*100
    row['fen']=board.fen()
    row['url']=game['headers'].get("_others",{}).get("LichessURL","")+f"#{move_number}"
    try:
        row['last_move']=san
    except:
        print(game)
        row['invalid']=True
    return row, evaluation['value']
row=build_stored_game_analysis(game, 4, 0)
row
# Out:
# ({'move_number': 4,
#   'taken': [],
#   'invalid': False,
#   'evaluation': 36,
#   'evaluation_change': 36,
#   'taken_score': 0,
#   'fen': 'rnbqkbnr/ppp2ppp/4p3/3p4/3PP3/8/PPP2PPP/RNBQKBNR w KQkq - 0 3',
#   'url': 'https://lichess.org/kuUOsOML#4',
#   'last_move': 'd7d5'},
#  36)

# %%
import random

#Used by chessnit.com
def build_stored_game_analysis(game, move_number):
    row={}
    row['move_number']=move_number
    row['taken']=[]
    board=chess.Board()
    for san in game['moves'][:move_number]:
        parsed_san=board.parse_san(san)
        taken=board.piece_at(parsed_san.to_square)
        if taken:
            row['taken'].append(taken.__str__())
        move=board.push_san(san)
    row['invalid']=bool(board.promoted) or bool(board.outcome())
    stockfish_good.set_fen_position(board.fen())
    evaluation=stockfish_good.get_evaluation()
    row['evaluation']=evaluation['value']
    
    
    row['taken_score']=sum([piece_scores.get(p) for p in row['taken']])*100
    row['fen']=board.fen()
    row['url']=game['headers'].get("_others",{}).get("LichessURL","")+f"#{move_number}"
    try:
        row['last_move']=san
    except:
        print(game)
        row['invalid']=True
    return row
row=build_stored_game_analysis(game, 20)
row
# Out:
# {'move_number': 20,
#  'taken': ['N', 'b', 'p', 'p', 'P', 'P'],
#  'invalid': False,
#  'evaluation': 72,
#  'taken_score': 0,
#  'fen': 'rnb1k1r1/ppq1np1Q/4p3/3pP3/8/P1p5/2P1NPPP/R1B1KB1R w KQq - 0 11',
#  'url': 'https://lichess.org/kuUOsOML#20',
#  'last_move': 'd4c3'}

# %%
import pandas as pd
import tqdm

def analyze_games(games, n, max_move_number):
    all_game_analysis = []
    
    # Iterate over the first n games in the DataFrame
    prev_evaluation  = 0
    for i in tqdm.tqdm(range(min(n, len(games)))):
        game = games.iloc[i]
        game_analysis = []
        
        # Analyze each game up to the specified move number
        for move_number in range(1, max_move_number + 1):
            analysis_result, current_evaluation = build_stored_game_analysis(game, move_number)
            game_analysis.append(analysis_result)
            prev_evaluation = current_evaluation
        # Store the analysis results for each game
        all_game_analysis.append(pd.DataFrame(game_analysis).set_index("move_number"))
    
    return all_game_analysis1

# %%
analyze_games(games, n_games, max_move_number)
# Out:
#   0%|          | 0/2 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# InvalidMoveError                          Traceback (most recent call last)
# Input In [76], in <cell line: 1>()
# ----> 1 analyze_games(games, n_games, max_move_number)
#
# Input In [75], in analyze_games(games, n, max_move_number)
#      13 # Analyze each game up to the specified move number
#      14 for move_number in range(1, max_move_number + 1):
# ---> 15     analysis_result, current_evaluation = build_stored_game_analysis(game, move_number)
#      16     game_analysis.append(analysis_result)
#      17     prev_evaluation = current_evaluation
#
# Input In [71], in build_stored_game_analysis(game, move_number)
#       8 board=chess.Board()
#       9 for san in game['moves'][:move_number]:
# ---> 10     parsed_san=board.parse_san(san)
#      11     taken=board.piece_at(parsed_san.to_square)
#      12     if taken:
#
# File ~\anaconda3\lib\site-packages\chess\__init__.py:3037, in Board.parse_san(self, san)
#    3035         raise InvalidMoveError(f"unsupported multi-leg move: {san!r}")
#    3036     else:
# -> 3037         raise InvalidMoveError(f"invalid san: {san!r}")
#    3039 # Get target square. Mask our own pieces to exclude castling moves.
#    3040 to_square = SQUARE_NAMES.index(match.group(4))
#
# InvalidMoveError: invalid san: '['

# %%
# Define the number of games and the maximum move number you want to analyze
n_games = 2  # For example, analyze the first 10 games
max_move_number = 15

# Assuming 'games' is your DataFrame containing the games
games_analysis = analyze_games(games, n_games, max_move_number)

# Now, games_analysis is a list of DataFrames, each containing the analysis of one game
# Out:
#   0%|          | 0/2 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# InvalidMoveError                          Traceback (most recent call last)
# Input In [77], in <cell line: 6>()
#       3 max_move_number = 15
#       5 # Assuming 'games' is your DataFrame containing the games
# ----> 6 games_analysis = analyze_games(games, n_games, max_move_number)
#
# Input In [75], in analyze_games(games, n, max_move_number)
#      13 # Analyze each game up to the specified move number
#      14 for move_number in range(1, max_move_number + 1):
# ---> 15     analysis_result, current_evaluation = build_stored_game_analysis(game, move_number)
#      16     game_analysis.append(analysis_result)
#      17     prev_evaluation = current_evaluation
#
# Input In [71], in build_stored_game_analysis(game, move_number)
#       8 board=chess.Board()
#       9 for san in game['moves'][:move_number]:
# ---> 10     parsed_san=board.parse_san(san)
#      11     taken=board.piece_at(parsed_san.to_square)
#      12     if taken:
#
# File ~\anaconda3\lib\site-packages\chess\__init__.py:3037, in Board.parse_san(self, san)
#    3035         raise InvalidMoveError(f"unsupported multi-leg move: {san!r}")
#    3036     else:
# -> 3037         raise InvalidMoveError(f"invalid san: {san!r}")
#    3039 # Get target square. Mask our own pieces to exclude castling moves.
#    3040 to_square = SQUARE_NAMES.index(match.group(4))
#
# InvalidMoveError: invalid san: '['

# %%
games_analysis
# Out:
# [                 taken  invalid  evaluation  evaluation_change  taken_score  \
#  move_number
#  1                   []    False          22                 22            0
#  2                   []    False          31                  9            0
#  3                   []    False          39                  8            0
#  4                   []    False          36                 -3            0
#  5                   []    False          36                  0            0
#  6                   []    False          69                 33            0
#  7                   []    False          71                  2            0
#  8                   []    False          87                 16            0
#  9                   []    False          65                -22            0
#  10                 [N]    False          66                  1         -300
#  11              [N, b]    False          75                  9            0
#  12              [N, b]    False          61                -14            0
#  13              [N, b]    False          69                  8            0
#  14              [N, b]    False          62                 -7            0
#  15           [N, b, p]    False          83                 21          100
#
#                                                             fen  \
#  move_number
#  1            rnbqkbnr/pppppppp/8/8/4P3/8/PPPP1PPP/RNBQKBNR ...
#  2            rnbqkbnr/pppp1ppp/4p3/8/4P3/8/PPPP1PPP/RNBQKBN...
#  3            rnbqkbnr/pppp1ppp/4p3/8/3PP3/8/PPP2PPP/RNBQKBN...
#  4            rnbqkbnr/ppp2ppp/4p3/3p4/3PP3/8/PPP2PPP/RNBQKB...
#  5            rnbqkbnr/ppp2ppp/4p3/3p4/3PP3/2N5/PPP2PPP/R1BQ...
#  6            rnbqk1nr/ppp2ppp/4p3/3p4/1b1PP3/2N5/PPP2PPP/R1...
#  7            rnbqk1nr/ppp2ppp/4p3/3pP3/1b1P4/2N5/PPP2PPP/R1...
#  8            rnbqk2r/ppp1nppp/4p3/3pP3/1b1P4/2N5/PPP2PPP/R1...
#  9            rnbqk2r/ppp1nppp/4p3/3pP3/1b1P4/P1N5/1PP2PPP/R...
#  10           rnbqk2r/ppp1nppp/4p3/3pP3/3P4/P1b5/1PP2PPP/R1B...
#  11           rnbqk2r/ppp1nppp/4p3/3pP3/3P4/P1P5/2P2PPP/R1BQ...
#  12           rnbqk2r/pp2nppp/4p3/2ppP3/3P4/P1P5/2P2PPP/R1BQ...
#  13           rnbqk2r/pp2nppp/4p3/2ppP3/3P2Q1/P1P5/2P2PPP/R1...
#  14           rnb1k2r/ppq1nppp/4p3/2ppP3/3P2Q1/P1P5/2P2PPP/R...
#  15           rnb1k2r/ppq1npQp/4p3/2ppP3/3P4/P1P5/2P2PPP/R1B...
#
#                                           url last_move
#  move_number
#  1             https://lichess.org/kuUOsOML#1      e2e4
#  2             https://lichess.org/kuUOsOML#2      e7e6
#  3             https://lichess.org/kuUOsOML#3      d2d4
#  4             https://lichess.org/kuUOsOML#4      d7d5
#  5             https://lichess.org/kuUOsOML#5      b1c3
#  6             https://lichess.org/kuUOsOML#6      f8b4
#  7             https://lichess.org/kuUOsOML#7      e4e5
#  8             https://lichess.org/kuUOsOML#8      g8e7
#  9             https://lichess.org/kuUOsOML#9      a2a3
#  10           https://lichess.org/kuUOsOML#10      b4c3
#  11           https://lichess.org/kuUOsOML#11      b2c3
#  12           https://lichess.org/kuUOsOML#12      c7c5
#  13           https://lichess.org/kuUOsOML#13      d1g4
#  14           https://lichess.org/kuUOsOML#14      d8c7
#  15           https://lichess.org/kuUOsOML#15      g4g7  ]

# %%
moves[['taken_score','evaluation']].plot(kind="bar")
# Out:
# <AxesSubplot:xlabel='move_number'>

# %%
#Look at the URL and compare against our evaluation
print(row['url'])
# Out:
# https://lichess.org/kuUOsOML#20

# %% [markdown]
# The most interesting games from a positional point of view are when the simple score by taken pieces and the evaluation differ.
# And it's most interesting to find the first move when that difference grew large enough to be notable. 2.92 is surely a notable score.

# %%
rows=[]
for move_number in tqdm.tqdm(range(1,15+1)):
    rows.append(build_stored_game_analysis(game, move_number))
moves=pd.DataFrame(rows).set_index("move_number")
moves
# Out:
# 100%|██████████| 15/15 [00:14<00:00,  1.07it/s]
#                  taken  invalid  evaluation  taken_score  \
# move_number
# 1                   []    False          22            0
# 2                   []    False          31            0
# 3                   []    False          39            0
# 4                   []    False          36            0
# 5                   []    False          36            0
# 6                   []    False          69            0
# 7                   []    False          71            0
# 8                   []    False          87            0
# 9                   []    False          65            0
# 10                 [N]    False          66         -300
# 11              [N, b]    False          75            0
# 12              [N, b]    False          61            0
# 13              [N, b]    False          69            0
# 14              [N, b]    False          62            0
# 15           [N, b, p]    False          83          100
#
#                                                            fen  \
# move_number
# 1            rnbqkbnr/pppppppp/8/8/4P3/8/PPPP1PPP/RNBQKBNR ...
# 2            rnbqkbnr/pppp1ppp/4p3/8/4P3/8/PPPP1PPP/RNBQKBN...
# 3            rnbqkbnr/pppp1ppp/4p3/8/3PP3/8/PPP2PPP/RNBQKBN...
# 4            rnbqkbnr/ppp2ppp/4p3/3p4/3PP3/8/PPP2PPP/RNBQKB...
# 5            rnbqkbnr/ppp2ppp/4p3/3p4/3PP3/2N5/PPP2PPP/R1BQ...
# 6            rnbqk1nr/ppp2ppp/4p3/3p4/1b1PP3/2N5/PPP2PPP/R1...
# 7            rnbqk1nr/ppp2ppp/4p3/3pP3/1b1P4/2N5/PPP2PPP/R1...
# 8            rnbqk2r/ppp1nppp/4p3/3pP3/1b1P4/2N5/PPP2PPP/R1...
# 9            rnbqk2r/ppp1nppp/4p3/3pP3/1b1P4/P1N5/1PP2PPP/R...
# 10           rnbqk2r/ppp1nppp/4p3/3pP3/3P4/P1b5/1PP2PPP/R1B...
# 11           rnbqk2r/ppp1nppp/4p3/3pP3/3P4/P1P5/2P2PPP/R1BQ...
# 12           rnbqk2r/pp2nppp/4p3/2ppP3/3P4/P1P5/2P2PPP/R1BQ...
# 13           rnbqk2r/pp2nppp/4p3/2ppP3/3P2Q1/P1P5/2P2PPP/R1...
# 14           rnb1k2r/ppq1nppp/4p3/2ppP3/3P2Q1/P1P5/2P2PPP/R...
# 15           rnb1k2r/ppq1npQp/4p3/2ppP3/3P4/P1P5/2P2PPP/R1B...
#
#                                          url last_move
# move_number
# 1             https://lichess.org/kuUOsOML#1      e2e4
# 2             https://lichess.org/kuUOsOML#2      e7e6
# 3             https://lichess.org/kuUOsOML#3      d2d4
# 4             https://lichess.org/kuUOsOML#4      d7d5
# 5             https://lichess.org/kuUOsOML#5      b1c3
# 6             https://lichess.org/kuUOsOML#6      f8b4
# 7             https://lichess.org/kuUOsOML#7      e4e5
# 8             https://lichess.org/kuUOsOML#8      g8e7
# 9             https://lichess.org/kuUOsOML#9      a2a3
# 10           https://lichess.org/kuUOsOML#10      b4c3
# 11           https://lichess.org/kuUOsOML#11      b2c3
# 12           https://lichess.org/kuUOsOML#12      c7c5
# 13           https://lichess.org/kuUOsOML#13      d1g4
# 14           https://lichess.org/kuUOsOML#14      d8c7
# 15           https://lichess.org/kuUOsOML#15      g4g7

# %%
moves[['taken_score','evaluation']].plot(kind="bar")
# Out:
# <AxesSubplot:xlabel='move_number'>

# %% [markdown]
# Cool! It's clear there are a few key moves. 14 is a minor mistake. 18 was a big blunder
